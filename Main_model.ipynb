# %%
import numpy as np
import nibabel as nib
import glob
from tensorflow.keras.utils import to_categorical
import matplotlib.pyplot as plt
from tifffile import imsave
from IPython.display import clear_output
from sklearn.preprocessing import MinMaxScaler
import os
import splitfolders
import random
import tensorflow as tf
from keras.models import Model
from keras.layers import Input, Conv3D, MaxPooling3D, concatenate, Conv3DTranspose, BatchNormalization, Dropout, Lambda
from tensorflow.keras.optimizers import Adam
from keras.metrics import MeanIoU
import keras
import segmentation_models_3D as sm
import pandas as pd
import time
import tensorflow.keras.backend as K
# Out:
# Segmentation Models: using `tf.keras` framework.

# %%
# import tensorflow as tf
tf.config.list_logical_devices()
# Out:
# [LogicalDevice(name='/device:CPU:0', device_type='CPU'),
#  LogicalDevice(name='/device:GPU:0', device_type='GPU')]

# %%
scaler = MinMaxScaler()

TRAIN_DATASET_PATH = "brats_2020/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_001/"
# TRAIN_DATASET_PATH = 'archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/'
#VALIDATION_DATASET_PATH = 'BraTS2020_ValidationData/MICCAI_BraTS2020_ValidationData'

test_image_flair=nib.load(TRAIN_DATASET_PATH + 'BraTS20_Training_001_flair.nii').get_fdata()
# print(test_image_flair)
print(test_image_flair.max())
#Scalers are applied to 1D so let us reshape and then reshape back to original shape. 
test_image_flair_scaled=scaler.fit_transform(test_image_flair.reshape(-1, test_image_flair.shape[-1])).reshape(test_image_flair.shape)

test_image_t1=nib.load(TRAIN_DATASET_PATH + 'BraTS20_Training_001_t1.nii').get_fdata()
test_image_t1=scaler.fit_transform(test_image_t1.reshape(-1, test_image_t1.shape[-1])).reshape(test_image_t1.shape)

test_image_t1ce=nib.load(TRAIN_DATASET_PATH + 'BraTS20_Training_001_t1ce.nii').get_fdata()
test_image_t1ce=scaler.fit_transform(test_image_t1ce.reshape(-1, test_image_t1ce.shape[-1])).reshape(test_image_t1ce.shape)

test_image_t2=nib.load(TRAIN_DATASET_PATH + 'BraTS20_Training_001_t2.nii').get_fdata()
test_image_t2=scaler.fit_transform(test_image_t2.reshape(-1, test_image_t2.shape[-1])).reshape(test_image_t2.shape)

test_mask=nib.load(TRAIN_DATASET_PATH + 'BraTS20_Training_001_seg.nii').get_fdata()
test_mask=test_mask.astype(np.uint8)

print(np.unique(test_mask))  #0, 1, 2, 4 (Need to reencode to 0, 1, 2, 3)
test_mask[test_mask==4] = 3  #Reassign mask values 4 to 3
print(np.unique(test_mask)) 

import random
n_slice=random.randint(0, test_mask.shape[2])

plt.figure(figsize=(12, 8))

plt.subplot(231)
plt.imshow(test_image_flair[:,:,n_slice], cmap='gray')
plt.title('Image flair')
plt.subplot(232)
plt.imshow(test_image_t1[:,:,n_slice], cmap='gray')
plt.title('Image t1')
plt.subplot(233)
plt.imshow(test_image_t1ce[:,:,n_slice], cmap='gray')
plt.title('Image t1ce')
plt.subplot(234)
plt.imshow(test_image_t2[:,:,n_slice], cmap='gray')
plt.title('Image t2')
plt.subplot(235)
plt.imshow(test_mask[:,:,n_slice])
plt.title('Mask')
plt.show()


##################################################
#PART 2: Explore the process of combining images to channels and divide them to patches
#Includes...
#Combining all 4 images to 4 channels of a numpy array.
#
################################################
#Flair, T1CE, annd T2 have the most information
#Combine t1ce, t2, and flair into single multichannel image

combined_x = np.stack([test_image_flair, test_image_t1ce, test_image_t2], axis=3)

#Crop to a size to be divisible by 64 so we can later extract 64x64x64 patches. 
#cropping x, y, and z
#combined_x=combined_x[24:216, 24:216, 13:141]

combined_x=combined_x[56:184, 56:184, 13:141] #Crop to 128x128x128x4

#Do the same for mask
test_mask = test_mask[56:184, 56:184, 13:141]

# n_slice=random.randint(0, test_mask.shape[2])
plt.figure(figsize=(12, 8))

plt.subplot(221)
plt.imshow(combined_x[:,:,n_slice, 0], cmap='gray')
plt.title('Image flair')
plt.subplot(222)
plt.imshow(combined_x[:,:,n_slice, 1], cmap='gray')
plt.title('Image t1ce')
plt.subplot(223)
plt.imshow(combined_x[:,:,n_slice, 2], cmap='gray')
plt.title('Image t2')
plt.subplot(224)
plt.imshow(test_mask[:,:,n_slice])
plt.title('Mask')
plt.show()
# Out:
# 625.0
# [0 1 2 4]
# [0 1 2 3]

# %%
scaler = MinMaxScaler()

#t1_list = sorted(glob.glob('BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/*/*t1.nii'))
t2_list = sorted(glob.glob('brats_2020/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/*/*t2.nii'))
t1ce_list = sorted(glob.glob('brats_2020/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/*/*t1ce.nii'))
flair_list = sorted(glob.glob('brats_2020/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/*/*flair.nii'))
mask_list = sorted(glob.glob('brats_2020/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/*/*seg.nii'))

#Each volume generates 18 64x64x64x4 sub-volumes. 
#Total 369 volumes = 6642 sub volumes
count=0
for img in range(len(t2_list)):   #Using t1_list as all lists are of same size
    print("Now preparing image and masks number: ", img)
      
    temp_image_t2=nib.load(t2_list[img]).get_fdata()
    temp_image_t2=scaler.fit_transform(temp_image_t2.reshape(-1, temp_image_t2.shape[-1])).reshape(temp_image_t2.shape)
   
    temp_image_t1ce=nib.load(t1ce_list[img]).get_fdata()
    temp_image_t1ce=scaler.fit_transform(temp_image_t1ce.reshape(-1, temp_image_t1ce.shape[-1])).reshape(temp_image_t1ce.shape)
   
    temp_image_flair=nib.load(flair_list[img]).get_fdata()
    temp_image_flair=scaler.fit_transform(temp_image_flair.reshape(-1, temp_image_flair.shape[-1])).reshape(temp_image_flair.shape)
        
    temp_mask=nib.load(mask_list[img]).get_fdata()
    temp_mask=temp_mask.astype(np.uint8)
    temp_mask[temp_mask==4] = 3  #Reassign mask values 4 to 3
    #print(np.unique(temp_mask))
    
    temp_combined_images = np.stack([temp_image_flair, temp_image_t1ce, temp_image_t2], axis=3)
    
    #Crop to a size to be divisible by 64 so we can later extract 64x64x64 patches. 
    #cropping x, y, and z
    temp_combined_images=temp_combined_images[56:184, 56:184, 13:141]
    temp_mask = temp_mask[56:184, 56:184, 13:141]
    
    val, counts = np.unique(temp_mask, return_counts=True)
    
    if (1 - (counts[0]/counts.sum())) > 0.01:  #At least 1% useful volume with labels that are not 0
        print("Save Me")
        temp_mask= to_categorical(temp_mask, num_classes=4)
        np.save('BraTS2020_TrainingData/input_data_3channels/images/image_'+str(img)+'.npy', temp_combined_images)
        np.save('BraTS2020_TrainingData/input_data_3channels/masks/mask_'+str(img)+'.npy', temp_mask)
        count+=1
    else:
        print("I am useless")
    clear_output(wait=True)

  
print(count)


input_folder = 'BraTS2020_TrainingData/input_data_3channels/'
output_folder = 'BraTS2020_TrainingData/input_data_128/'
# Split with a ratio.
# To only split into training and validation set, set a tuple to `ratio`, i.e, `(.8, .2)`.
splitfolders.ratio(input_folder, output=output_folder, seed=42, ratio=(.70, .20, .10), group_prefix=None) # default values
# Out:
# 344

# %%
def load_img(img_dir, img_list):
    images=[]
    for i, image_name in enumerate(img_list):    
        if (image_name.split('.')[1] == 'npy'):
            
            image = np.load(img_dir+image_name)
                      
            images.append(image)
    images = np.array(images)
    
    return(images)


def imageLoader(img_dir, img_list, mask_dir, mask_list, batch_size):

    L = len(img_list)

    #keras needs the generator infinite, so we will use while true  
    while True:

        batch_start = 0
        batch_end = batch_size

        while batch_start < L:
            limit = min(batch_end, L)
                       
            X = load_img(img_dir, img_list[batch_start:limit])
            Y = load_img(mask_dir, mask_list[batch_start:limit])

            yield (X,Y) #a tuple with two numpy arrays with batch_size samples     

            batch_start += batch_size   
            batch_end += batch_size

# %%
kernel_initializer =  'he_uniform' #Try others if you want
# kernel_initializer = 'TruncatedNormal'
################################################################
def simple_unet_model(IMG_HEIGHT, IMG_WIDTH, IMG_DEPTH, IMG_CHANNELS, num_classes):
#Build the model
    inputs = Input((IMG_HEIGHT, IMG_WIDTH, IMG_DEPTH, IMG_CHANNELS))
    #s = Lambda(lambda x: x / 255)(inputs)   #No need for this if we normalize our inputs beforehand
    s = inputs

    #Contraction path
    c1 = Conv3D(16, (3, 3, 3), activation='relu', kernel_initializer=kernel_initializer, padding='same')(s)
    c1 = Dropout(0.1)(c1)
    c1 = Conv3D(16, (3, 3, 3), activation='relu', kernel_initializer=kernel_initializer, padding='same')(c1)
    p1 = MaxPooling3D((2, 2, 2))(c1)

    c2 = Conv3D(32, (3, 3, 3), activation='relu', kernel_initializer=kernel_initializer, padding='same')(p1)
    c2 = Dropout(0.1)(c2)
    c2 = Conv3D(32, (3, 3, 3), activation='relu', kernel_initializer=kernel_initializer, padding='same')(c2)
    p2 = MaxPooling3D((2, 2, 2))(c2)

    c3 = Conv3D(64, (3, 3, 3), activation='relu', kernel_initializer=kernel_initializer, padding='same')(p2)
    c3 = Dropout(0.2)(c3)
    c3 = Conv3D(64, (3, 3, 3), activation='relu', kernel_initializer=kernel_initializer, padding='same')(c3)
    p3 = MaxPooling3D((2, 2, 2))(c3)

    c4 = Conv3D(128, (3, 3, 3), activation='relu', kernel_initializer=kernel_initializer, padding='same')(p3)
    c4 = Dropout(0.2)(c4)
    c4 = Conv3D(128, (3, 3, 3), activation='relu', kernel_initializer=kernel_initializer, padding='same')(c4)
    p4 = MaxPooling3D(pool_size=(2, 2, 2))(c4)

    c5 = Conv3D(256, (3, 3, 3), activation='relu', kernel_initializer=kernel_initializer, padding='same')(p4)
    c5 = Dropout(0.3)(c5)
    c5 = Conv3D(256, (3, 3, 3), activation='relu', kernel_initializer=kernel_initializer, padding='same')(c5)

    #Expansive path
    u6 = Conv3DTranspose(128, (2, 2, 2), strides=(2, 2, 2), padding='same')(c5)
    u6 = concatenate([u6, c4])
    c6 = Conv3D(128, (3, 3, 3), activation='relu', kernel_initializer=kernel_initializer, padding='same')(u6)
    c6 = Dropout(0.2)(c6)
    c6 = Conv3D(128, (3, 3, 3), activation='relu', kernel_initializer=kernel_initializer, padding='same')(c6)

    u7 = Conv3DTranspose(64, (2, 2, 2), strides=(2, 2, 2), padding='same')(c6)
    u7 = concatenate([u7, c3])
    c7 = Conv3D(64, (3, 3, 3), activation='relu', kernel_initializer=kernel_initializer, padding='same')(u7)
    c7 = Dropout(0.2)(c7)
    c7 = Conv3D(64, (3, 3, 3), activation='relu', kernel_initializer=kernel_initializer, padding='same')(c7)

    u8 = Conv3DTranspose(32, (2, 2, 2), strides=(2, 2, 2), padding='same')(c7)
    u8 = concatenate([u8, c2])
    c8 = Conv3D(32, (3, 3, 3), activation='relu', kernel_initializer=kernel_initializer, padding='same')(u8)
    c8 = Dropout(0.1)(c8)
    c8 = Conv3D(32, (3, 3, 3), activation='relu', kernel_initializer=kernel_initializer, padding='same')(c8)

    u9 = Conv3DTranspose(16, (2, 2, 2), strides=(2, 2, 2), padding='same')(c8)
    u9 = concatenate([u9, c1])
    c9 = Conv3D(16, (3, 3, 3), activation='relu', kernel_initializer=kernel_initializer, padding='same')(u9)
    c9 = Dropout(0.1)(c9)
    c9 = Conv3D(16, (3, 3, 3), activation='relu', kernel_initializer=kernel_initializer, padding='same')(c9)

    outputs = Conv3D(num_classes, (1, 1, 1), activation='softmax')(c9)

    model = Model(inputs=[inputs], outputs=[outputs])
    #compile model outside of this function to make it flexible.
    model.summary()
    tf.keras.utils.plot_model(model, show_shapes=True)
    img_file = './model_arch.png'

    tf.keras.utils.plot_model(model, to_file=img_file, show_shapes=True, show_layer_names=True)
    return model

#Test if everything is working ok.
model = simple_unet_model(128, 128, 128, 3, 4)
# print(model.input_shape)
# print(model.output_shape)
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 128, 128, 1  0           []
#                                 28, 3)]
#
#  conv3d (Conv3D)                (None, 128, 128, 12  1312        ['input_1[0][0]']
#                                 8, 16)
#
#  dropout (Dropout)              (None, 128, 128, 12  0           ['conv3d[0][0]']
#                                 8, 16)
#
#  conv3d_1 (Conv3D)              (None, 128, 128, 12  6928        ['dropout[0][0]']
#                                 8, 16)
#
#  max_pooling3d (MaxPooling3D)   (None, 64, 64, 64,   0           ['conv3d_1[0][0]']
#                                 16)
#
#  conv3d_2 (Conv3D)              (None, 64, 64, 64,   13856       ['max_pooling3d[0][0]']
#                                 32)
#
#  dropout_1 (Dropout)            (None, 64, 64, 64,   0           ['conv3d_2[0][0]']
#                                 32)
#
#  conv3d_3 (Conv3D)              (None, 64, 64, 64,   27680       ['dropout_1[0][0]']
#                                 32)
#
#  max_pooling3d_1 (MaxPooling3D)  (None, 32, 32, 32,   0          ['conv3d_3[0][0]']
#                                 32)
#
#  conv3d_4 (Conv3D)              (None, 32, 32, 32,   55360       ['max_pooling3d_1[0][0]']
#                                 64)
#
#  dropout_2 (Dropout)            (None, 32, 32, 32,   0           ['conv3d_4[0][0]']
#                                 64)
#
#  conv3d_5 (Conv3D)              (None, 32, 32, 32,   110656      ['dropout_2[0][0]']
#                                 64)
#
#  max_pooling3d_2 (MaxPooling3D)  (None, 16, 16, 16,   0          ['conv3d_5[0][0]']
#                                 64)
#
#  conv3d_6 (Conv3D)              (None, 16, 16, 16,   221312      ['max_pooling3d_2[0][0]']
#                                 128)
#
#  dropout_3 (Dropout)            (None, 16, 16, 16,   0           ['conv3d_6[0][0]']
#                                 128)
#
#  conv3d_7 (Conv3D)              (None, 16, 16, 16,   442496      ['dropout_3[0][0]']
#                                 128)
#
#  max_pooling3d_3 (MaxPooling3D)  (None, 8, 8, 8, 128  0          ['conv3d_7[0][0]']
#                                 )
#
#  conv3d_8 (Conv3D)              (None, 8, 8, 8, 256  884992      ['max_pooling3d_3[0][0]']
#                                 )
#
#  dropout_4 (Dropout)            (None, 8, 8, 8, 256  0           ['conv3d_8[0][0]']
#                                 )
#
#  conv3d_9 (Conv3D)              (None, 8, 8, 8, 256  1769728     ['dropout_4[0][0]']
#                                 )
#
#  conv3d_transpose (Conv3DTransp  (None, 16, 16, 16,   262272     ['conv3d_9[0][0]']
#  ose)                           128)
#
#  concatenate (Concatenate)      (None, 16, 16, 16,   0           ['conv3d_transpose[0][0]',
#                                 256)                              'conv3d_7[0][0]']
#
#  conv3d_10 (Conv3D)             (None, 16, 16, 16,   884864      ['concatenate[0][0]']
#                                 128)
#
#  dropout_5 (Dropout)            (None, 16, 16, 16,   0           ['conv3d_10[0][0]']
#                                 128)
#
#  conv3d_11 (Conv3D)             (None, 16, 16, 16,   442496      ['dropout_5[0][0]']
#                                 128)
#
#  conv3d_transpose_1 (Conv3DTran  (None, 32, 32, 32,   65600      ['conv3d_11[0][0]']
#  spose)                         64)
#
#  concatenate_1 (Concatenate)    (None, 32, 32, 32,   0           ['conv3d_transpose_1[0][0]',
#                                 128)                              'conv3d_5[0][0]']
#
#  conv3d_12 (Conv3D)             (None, 32, 32, 32,   221248      ['concatenate_1[0][0]']
#                                 64)
#
#  dropout_6 (Dropout)            (None, 32, 32, 32,   0           ['conv3d_12[0][0]']
#                                 64)
#
#  conv3d_13 (Conv3D)             (None, 32, 32, 32,   110656      ['dropout_6[0][0]']
#                                 64)
#
#  conv3d_transpose_2 (Conv3DTran  (None, 64, 64, 64,   16416      ['conv3d_13[0][0]']
#  spose)                         32)
#
#  concatenate_2 (Concatenate)    (None, 64, 64, 64,   0           ['conv3d_transpose_2[0][0]',
#                                 64)                               'conv3d_3[0][0]']
#
#  conv3d_14 (Conv3D)             (None, 64, 64, 64,   55328       ['concatenate_2[0][0]']
#                                 32)
#
#  dropout_7 (Dropout)            (None, 64, 64, 64,   0           ['conv3d_14[0][0]']
#                                 32)
#
#  conv3d_15 (Conv3D)             (None, 64, 64, 64,   27680       ['dropout_7[0][0]']
#                                 32)
#
#  conv3d_transpose_3 (Conv3DTran  (None, 128, 128, 12  4112       ['conv3d_15[0][0]']
#  spose)                         8, 16)
#
#  concatenate_3 (Concatenate)    (None, 128, 128, 12  0           ['conv3d_transpose_3[0][0]',
#                                 8, 32)                            'conv3d_1[0][0]']
#
#  conv3d_16 (Conv3D)             (None, 128, 128, 12  13840       ['concatenate_3[0][0]']
#                                 8, 16)
#
#  dropout_8 (Dropout)            (None, 128, 128, 12  0           ['conv3d_16[0][0]']
#                                 8, 16)
#
#  conv3d_17 (Conv3D)             (None, 128, 128, 12  6928        ['dropout_8[0][0]']
#                                 8, 16)
#
#  conv3d_18 (Conv3D)             (None, 128, 128, 12  68          ['conv3d_17[0][0]']
#                                 8, 4)
#
# ==================================================================================================
# Total params: 5,645,828
# Trainable params: 5,645,828
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import Model

from tensorflow.keras.utils import plot_model
from tensorflow.keras.layers import Input, Dense, BatchNormalization
from IPython.core.display import Image
keras.utils.plot_model(model, show_shapes=True)

# %%
train_img_dir = "BraTS2020_TrainingData/input_data_128/train/images/"
train_mask_dir = "BraTS2020_TrainingData/input_data_128/train/masks/"

val_img_dir = "BraTS2020_TrainingData/input_data_128/val/images/"
val_mask_dir = "BraTS2020_TrainingData/input_data_128/val/masks/"

test_img_dir = "BraTS2020_TrainingData/input_data_128/test/images/"
test_mask_dir = "BraTS2020_TrainingData/input_data_128/test/masks/"

test_img_list=os.listdir(test_img_dir)
test_mask_list = os.listdir(test_mask_dir)

train_img_list=os.listdir(train_img_dir)
train_mask_list = os.listdir(train_mask_dir)

val_img_list=os.listdir(val_img_dir)
val_mask_list = os.listdir(val_mask_dir)
##################################



batch_size=8 #Check IoU for a batch of images
test_img_datagen = imageLoader(test_img_dir, test_img_list, 
                                test_mask_dir, test_mask_list, batch_size)

test_steps_per_epoch = len(test_img_list)//batch_size
########################################################################
batch_size = 2

train_img_datagen = imageLoader(train_img_dir, train_img_list, 
                                train_mask_dir, train_mask_list, batch_size)

val_img_datagen = imageLoader(val_img_dir, val_img_list, 
                                val_mask_dir, val_mask_list, batch_size)


###########################################################################
#Define loss, metrics and optimizer to be used for training
wt0, wt1, wt2, wt3 = 0.25,0.25,0.25,0.25

dice_loss = sm.losses.DiceLoss(class_weights=np.array([wt0, wt1, wt2, wt3])) 
focal_loss = sm.losses.CategoricalFocalLoss()
total_loss = dice_loss + (1 * focal_loss)

def dice_coefficient(y_true, y_pred, smooth=1):
    intersection = K.sum(y_true * y_pred, axis=[1,2,3,4])
    union = K.sum(y_true, axis=[1,2,3,4]) + K.sum(y_pred, axis=[1,2,3,4])
    dice = K.mean((2. * intersection + smooth) / (union + smooth), axis=0)
    return dice

def dice_loss(y_true, y_pred):
    return 1 - dice_coefficient(y_true, y_pred)

metrics_1 = ['accuracy', sm.metrics.IOUScore(threshold=0.5), dice_coefficient,dice_loss,total_loss]

LR = 0.0001
optim_1 = tf.keras.optimizers.Adam(LR)
#######################################################################
#Fit the model 

steps_per_epoch = len(train_img_list)//batch_size
val_steps_per_epoch = len(val_img_list)//batch_size
model_1 = simple_unet_model(IMG_HEIGHT=128, 
                          IMG_WIDTH=128, 
                          IMG_DEPTH=128, 
                          IMG_CHANNELS=3, 
                          num_classes=4)

model_1.compile(optimizer = optim_1, loss='categorical_crossentropy', metrics=metrics_1)
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 128, 128, 1  0           []
#                                 28, 3)]
#
#  conv3d (Conv3D)                (None, 128, 128, 12  1312        ['input_1[0][0]']
#                                 8, 16)
#
#  dropout (Dropout)              (None, 128, 128, 12  0           ['conv3d[0][0]']
#                                 8, 16)
#
#  conv3d_1 (Conv3D)              (None, 128, 128, 12  6928        ['dropout[0][0]']
#                                 8, 16)
#
#  max_pooling3d (MaxPooling3D)   (None, 64, 64, 64,   0           ['conv3d_1[0][0]']
#                                 16)
#
#  conv3d_2 (Conv3D)              (None, 64, 64, 64,   13856       ['max_pooling3d[0][0]']
#                                 32)
#
#  dropout_1 (Dropout)            (None, 64, 64, 64,   0           ['conv3d_2[0][0]']
#                                 32)
#
#  conv3d_3 (Conv3D)              (None, 64, 64, 64,   27680       ['dropout_1[0][0]']
#                                 32)
#
#  max_pooling3d_1 (MaxPooling3D)  (None, 32, 32, 32,   0          ['conv3d_3[0][0]']
#                                 32)
#
#  conv3d_4 (Conv3D)              (None, 32, 32, 32,   55360       ['max_pooling3d_1[0][0]']
#                                 64)
#
#  dropout_2 (Dropout)            (None, 32, 32, 32,   0           ['conv3d_4[0][0]']
#                                 64)
#
#  conv3d_5 (Conv3D)              (None, 32, 32, 32,   110656      ['dropout_2[0][0]']
#                                 64)
#
#  max_pooling3d_2 (MaxPooling3D)  (None, 16, 16, 16,   0          ['conv3d_5[0][0]']
#                                 64)
#
#  conv3d_6 (Conv3D)              (None, 16, 16, 16,   221312      ['max_pooling3d_2[0][0]']
#                                 128)
#
#  dropout_3 (Dropout)            (None, 16, 16, 16,   0           ['conv3d_6[0][0]']
#                                 128)
#
#  conv3d_7 (Conv3D)              (None, 16, 16, 16,   442496      ['dropout_3[0][0]']
#                                 128)
#
#  max_pooling3d_3 (MaxPooling3D)  (None, 8, 8, 8, 128  0          ['conv3d_7[0][0]']
#                                 )
#
#  conv3d_8 (Conv3D)              (None, 8, 8, 8, 256  884992      ['max_pooling3d_3[0][0]']
#                                 )
#
#  dropout_4 (Dropout)            (None, 8, 8, 8, 256  0           ['conv3d_8[0][0]']
#                                 )
#
#  conv3d_9 (Conv3D)              (None, 8, 8, 8, 256  1769728     ['dropout_4[0][0]']
#                                 )
#
#  conv3d_transpose (Conv3DTransp  (None, 16, 16, 16,   262272     ['conv3d_9[0][0]']
#  ose)                           128)
#
#  concatenate (Concatenate)      (None, 16, 16, 16,   0           ['conv3d_transpose[0][0]',
#                                 256)                              'conv3d_7[0][0]']
#
#  conv3d_10 (Conv3D)             (None, 16, 16, 16,   884864      ['concatenate[0][0]']
#                                 128)
#
#  dropout_5 (Dropout)            (None, 16, 16, 16,   0           ['conv3d_10[0][0]']
#                                 128)
#
#  conv3d_11 (Conv3D)             (None, 16, 16, 16,   442496      ['dropout_5[0][0]']
#                                 128)
#
#  conv3d_transpose_1 (Conv3DTran  (None, 32, 32, 32,   65600      ['conv3d_11[0][0]']
#  spose)                         64)
#
#  concatenate_1 (Concatenate)    (None, 32, 32, 32,   0           ['conv3d_transpose_1[0][0]',
#                                 128)                              'conv3d_5[0][0]']
#
#  conv3d_12 (Conv3D)             (None, 32, 32, 32,   221248      ['concatenate_1[0][0]']
#                                 64)
#
#  dropout_6 (Dropout)            (None, 32, 32, 32,   0           ['conv3d_12[0][0]']
#                                 64)
#
#  conv3d_13 (Conv3D)             (None, 32, 32, 32,   110656      ['dropout_6[0][0]']
#                                 64)
#
#  conv3d_transpose_2 (Conv3DTran  (None, 64, 64, 64,   16416      ['conv3d_13[0][0]']
#  spose)                         32)
#
#  concatenate_2 (Concatenate)    (None, 64, 64, 64,   0           ['conv3d_transpose_2[0][0]',
#                                 64)                               'conv3d_3[0][0]']
#
#  conv3d_14 (Conv3D)             (None, 64, 64, 64,   55328       ['concatenate_2[0][0]']
#                                 32)
#
#  dropout_7 (Dropout)            (None, 64, 64, 64,   0           ['conv3d_14[0][0]']
#                                 32)
#
#  conv3d_15 (Conv3D)             (None, 64, 64, 64,   27680       ['dropout_7[0][0]']
#                                 32)
#
#  conv3d_transpose_3 (Conv3DTran  (None, 128, 128, 12  4112       ['conv3d_15[0][0]']
#  spose)                         8, 16)
#
#  concatenate_3 (Concatenate)    (None, 128, 128, 12  0           ['conv3d_transpose_3[0][0]',
#                                 8, 32)                            'conv3d_1[0][0]']
#
#  conv3d_16 (Conv3D)             (None, 128, 128, 12  13840       ['concatenate_3[0][0]']
#                                 8, 16)
#
#  dropout_8 (Dropout)            (None, 128, 128, 12  0           ['conv3d_16[0][0]']
#                                 8, 16)
#
#  conv3d_17 (Conv3D)             (None, 128, 128, 12  6928        ['dropout_8[0][0]']
#                                 8, 16)
#
#  conv3d_18 (Conv3D)             (None, 128, 128, 12  68          ['conv3d_17[0][0]']
#                                 8, 4)
#
# ==================================================================================================
# Total params: 5,645,828
# Trainable params: 5,645,828
# Non-trainable params: 0
# __________________________________________________________________________________________________
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model/model_to_dot to work.
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model/model_to_dot to work.

# %%
start_time = time.time()

print(model_1.summary())

print(model_1.input_shape)
print(model_1.output_shape)
clear_output(wait=True)
history_1 = model_1.fit(train_img_datagen,
          steps_per_epoch=steps_per_epoch,
          epochs=400,
          verbose=1,
          validation_data=val_img_datagen,
          validation_steps=val_steps_per_epoch,
          )


model_1.save('brats_3d.hdf5')
##################################################################
end_time = time.time()
runtime_seconds = end_time - start_time

# Convert runtime to hours, minutes, and seconds
hours = int(runtime_seconds // 3600)
minutes = int((runtime_seconds % 3600) // 60)
seconds = int(runtime_seconds % 60)

print(f"Runtime: {hours} hours, {minutes} minutes, {seconds} seconds")
# Out:
# Epoch 1/400
# 120/120 [==============================] - 134s 937ms/step - loss: 0.4782 - accuracy: 0.8481 - iou_score: 0.1991 - dice_coefficient: 0.7723 - dice_loss: 0.2277 - dice_loss_plus_1focal_loss: 0.9597 - val_loss: 0.3010 - val_accuracy: 0.9500 - val_iou_score: 0.2279 - val_dice_coefficient: 0.7981 - val_dice_loss: 0.2019 - val_dice_loss_plus_1focal_loss: 0.9397
# Epoch 2/400
# 120/120 [==============================] - 109s 909ms/step - loss: 0.1953 - accuracy: 0.9521 - iou_score: 0.2388 - dice_coefficient: 0.9124 - dice_loss: 0.0876 - dice_loss_plus_1focal_loss: 0.9347 - val_loss: 0.2955 - val_accuracy: 0.9513 - val_iou_score: 0.2255 - val_dice_coefficient: 0.7970 - val_dice_loss: 0.2030 - val_dice_loss_plus_1focal_loss: 0.9363
# Epoch 3/400
# 120/120 [==============================] - 109s 908ms/step - loss: 0.1782 - accuracy: 0.9530 - iou_score: 0.2399 - dice_coefficient: 0.9192 - dice_loss: 0.0808 - dice_loss_plus_1focal_loss: 0.9296 - val_loss: 0.1664 - val_accuracy: 0.9517 - val_iou_score: 0.2409 - val_dice_coefficient: 0.9177 - val_dice_loss: 0.0823 - val_dice_loss_plus_1focal_loss: 0.9272
# Epoch 4/400
# 120/120 [==============================] - 109s 908ms/step - loss: 0.1618 - accuracy: 0.9545 - iou_score: 0.2408 - dice_coefficient: 0.9256 - dice_loss: 0.0744 - dice_loss_plus_1focal_loss: 0.9253 - val_loss: 0.1581 - val_accuracy: 0.9542 - val_iou_score: 0.2414 - val_dice_coefficient: 0.9246 - val_dice_loss: 0.0754 - val_dice_loss_plus_1focal_loss: 0.9244
# Epoch 5/400
# 120/120 [==============================] - 109s 909ms/step - loss: 0.1525 - accuracy: 0.9567 - iou_score: 0.2416 - dice_coefficient: 0.9295 - dice_loss: 0.0705 - dice_loss_plus_1focal_loss: 0.9217 - val_loss: 0.1504 - val_accuracy: 0.9575 - val_iou_score: 0.2419 - val_dice_coefficient: 0.9283 - val_dice_loss: 0.0717 - val_dice_loss_plus_1focal_loss: 0.9207
# Epoch 6/400
# 120/120 [==============================] - 109s 909ms/step - loss: 0.1414 - accuracy: 0.9587 - iou_score: 0.2470 - dice_coefficient: 0.9342 - dice_loss: 0.0658 - dice_loss_plus_1focal_loss: 0.9173 - val_loss: 0.1448 - val_accuracy: 0.9596 - val_iou_score: 0.2436 - val_dice_coefficient: 0.9300 - val_dice_loss: 0.0700 - val_dice_loss_plus_1focal_loss: 0.9178
# Epoch 7/400
# 120/120 [==============================] - 109s 908ms/step - loss: 0.1346 - accuracy: 0.9600 - iou_score: 0.2595 - dice_coefficient: 0.9372 - dice_loss: 0.0628 - dice_loss_plus_1focal_loss: 0.9144 - val_loss: 0.1397 - val_accuracy: 0.9603 - val_iou_score: 0.2511 - val_dice_coefficient: 0.9354 - val_dice_loss: 0.0646 - val_dice_loss_plus_1focal_loss: 0.9158
# Epoch 8/400
# 120/120 [==============================] - 109s 909ms/step - loss: 0.
400
# 120/120 [==============================] - 109s 907ms/step - loss: 0.0142 - accuracy: 0.9942 - iou_score: 0.8520 - dice_coefficient: 0.9918 - dice_loss: 0.0082 - dice_loss_plus_1focal_loss: 0.7807 - val_loss: 0.1163 - val_accuracy: 0.9804 - val_iou_score: 0.6217 - val_dice_coefficient: 0.9792 - val_dice_loss: 0.0208 - val_dice_loss_plus_1focal_loss: 0.8264
# Epoch 396/400
# 120/120 [==============================] - 109s 907ms/step - loss: 0.0138 - accuracy: 0.9944 - iou_score: 0.8542 - dice_coefficient: 0.9920 - dice_loss: 0.0080 - dice_loss_plus_1focal_loss: 0.7803 - val_loss: 0.1305 - val_accuracy: 0.9802 - val_iou_score: 0.6174 - val_dice_coefficient: 0.9791 - val_dice_loss: 0.0209 - val_dice_loss_plus_1focal_loss: 0.8280
# Epoch 397/400
# 120/120 [==============================] - 109s 907ms/step - loss: 0.0136 - accuracy: 0.9945 - iou_score: 0.8556 - dice_coefficient: 0.9920 - dice_loss: 0.0080 - dice_loss_plus_1focal_loss: 0.7802 - val_loss: 0.1368 - val_accuracy: 0.9796 - val_iou_score: 0.6064 - val_dice_coefficient: 0.9785 - val_dice_loss: 0.0215 - val_dice_loss_plus_1focal_loss: 0.8309
# Epoch 398/400
# 120/120 [==============================] - 109s 907ms/step - loss: 0.0135 - accuracy: 0.9945 - iou_score: 0.8554 - dice_coefficient: 0.9921 - dice_loss: 0.0079 - dice_loss_plus_1focal_loss: 0.7802 - val_loss: 0.1215 - val_accuracy: 0.9800 - val_iou_score: 0.6033 - val_dice_coefficient: 0.9788 - val_dice_loss: 0.0212 - val_dice_loss_plus_1focal_loss: 0.8309
# Epoch 399/400
# 120/120 [==============================] - 109s 907ms/step - loss: 0.0133 - accuracy: 0.9946 - iou_score: 0.8582 - dice_coefficient: 0.9923 - dice_loss: 0.0077 - dice_loss_plus_1focal_loss: 0.7799 - val_loss: 0.1090 - val_accuracy: 0.9809 - val_iou_score: 0.6269 - val_dice_coefficient: 0.9795 - val_dice_loss: 0.0205 - val_dice_loss_plus_1focal_loss: 0.8261
# Epoch 400/400
# 120/120 [==============================] - 109s 907ms/step - loss: 0.0132 - accuracy: 0.9946 - iou_score: 0.8568 - dice_coefficient: 0.9923 - dice_loss: 0.0077 - dice_loss_plus_1focal_loss: 0.7799 - val_loss: 0.0952 - val_accuracy: 0.9813 - val_iou_score: 0.6389 - val_dice_coefficient: 0.9796 - val_dice_loss: 0.0204 - val_dice_loss_plus_1focal_loss: 0.8240
# Runtime: 12 hours, 6 minutes, 13 seconds

# %%
print(model_1.metrics_names)
# Out:
# ['loss', 'accuracy', 'iou_score', 'dice_coefficient', 'dice_loss', 'dice_loss_plus_1focal_loss']

# %% [markdown]
# # test image

# %%
img_num = 82

test_img = np.load("BraTS2020_TrainingData/input_data_128/test/images/image_"+str(img_num)+".npy")

test_mask = np.load("BraTS2020_TrainingData/input_data_128/test/masks/mask_"+str(img_num)+".npy")
test_mask_argmax=np.argmax(test_mask, axis=3)

test_img_input = np.expand_dims(test_img, axis=0)
test_prediction = model_1.predict(test_img_input)
test_prediction_argmax=np.argmax(test_prediction, axis=4)[0,:,:,:]


print(test_prediction_argmax.shape)
print(test_mask_argmax.shape)
print(np.unique(test_prediction_argmax))


#Plot individual slices from test predictions for verification
from matplotlib import pyplot as plt
import random

#n_slice=random.randint(0, test_prediction_argmax.shape[2])
n_slice = 55
plt.figure(figsize=(12, 8))
plt.subplot(231)
plt.title('Testing Image')
plt.imshow(test_img[:,:,n_slice,2])
plt.subplot(232)
plt.title('Testing Label')
plt.imshow(test_mask_argmax[:,:,n_slice])
plt.subplot(233)
plt.title('Prediction on test image')
plt.imshow(test_prediction_argmax[:,:, n_slice])
plt.show()
# Out:
# (128, 128, 128)
# (128, 128, 128)
# [0 1 2 3]

# %%
#plot the training and validation IoU and loss at each epoch

loss = history_1.history['loss']
val_loss = history_1.history['val_loss']
dice_score = history_1.history['dice_coefficient']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
# plt.plot(epochs, dice_score, 'g', label='dice_score')
plt.title('Training and validation loss and dice')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

acc = history_1.history['accuracy']
val_acc = history_1.history['val_accuracy']

plt.plot(epochs, acc, 'y', label='Training accuracy')
plt.plot(epochs, val_acc, 'r', label='Validation accuracy')
plt.plot(epochs, dice_score, 'b', label='dice_score')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
#Verify IoU on a batch of images from the test dataset
#Using built in keras function for IoU
#Only works on TF > 2.0
from keras.metrics import MeanIoU

#Verify generator.... In python 3 next() is renamed as __next__()
test_image_batch, test_mask_batch = test_img_datagen.__next__()

test_mask_batch_argmax = np.argmax(test_mask_batch, axis=4)
test_pred_batch = model_1.predict(test_image_batch)
test_pred_batch_argmax = np.argmax(test_pred_batch, axis=4)

n_classes = 4
IOU_keras = MeanIoU(num_classes=n_classes)  
IOU_keras.update_state(test_pred_batch_argmax, test_mask_batch_argmax)
print("Mean IoU =", IOU_keras.result().numpy())
# Out:
# Mean IoU = 0.68462294

# %%
model_1.compile(optimizer = optim_1, loss='categorical_crossentropy', metrics=metrics_1)

print("Evaluate on test data")
accuracy, iou_score, iou_score, dice_coefficient,dice_loss, dice_loss_plus_1focal_loss = model_1.evaluate(test_img_datagen, batch_size=16, 
                                                                                                          verbose =1, steps=test_steps_per_epoch)
print("Test Loss: ", accuracy)
print("Accuracy: ", iou_score)
print("dice score: ", iou_score)
print("dice_coefficient ", dice_coefficient)
print("dice_loss ", dice_loss)
print("dice_loss_plus_1focal_loss ", dice_loss_plus_1focal_loss)
# Out:
# Evaluate on test data
# 4/4 [==============================] - 8s 2s/step - loss: 0.1083 - accuracy: 0.9785 - iou_score: 0.6087 - dice_coefficient: 0.9762 - dice_loss: 0.0238 - dice_loss_plus_1focal_loss: 0.8290
# Test Loss:  0.10828550904989243
# Accuracy:  0.6086890697479248
# dice score:  0.6086890697479248
# dice_coefficient  0.976249098777771
# dice_loss  0.02375093102455139
# dice_loss_plus_1focal_loss  0.8290437459945679

# %%
# accuracy,iou_score,iou_score,dice_coefficient,dice_loss,dice_loss_plus_1focal_loss = my_model.evaluate(val_img_datagen, steps=val_steps_per_epoch)

# print("Test Loss: ", test_loss)
# print("Accuracy: ", test_dice)
# print("dice score: ", test_dice_loss)

# %% [markdown]
# # new edits (model number 2)

# %%
# dice loss as defined above for 4 classes
def dice_coef_2(y_true, y_pred, smooth=1.0):
    class_num = 4
    for i in range(class_num):
        y_true_f = K.flatten(y_true[:,:,:,:,i])
        y_pred_f = K.flatten(y_pred[:,:,:,:,i])
        intersection = K.sum(y_true_f * y_pred_f)
        loss = ((2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth))
   #     K.print_tensor(loss, message='loss value for class {} : '.format(SEGMENT_CLASSES[i]))
        if i == 0:
            total_loss = loss
        else:
            total_loss = total_loss + loss
            
    total_loss = total_loss / class_num
#    K.print_tensor(total_loss, message=' total dice coef: ')
    return total_loss

# define per class evaluation of dice coef
# inspired by https://github.com/keras-team/keras/issues/9395
def dice_coef_necrotic_2(y_true, y_pred, epsilon=1e-6):
    intersection = K.sum(K.abs(y_true[:,:,:,:,1] * y_pred[:,:,:,:,1]))
    return (2. * intersection) / (K.sum(K.square(y_true[:,:,:,:,1])) + K.sum(K.square(y_pred[:,:,:,1])) + epsilon)

def dice_coef_edema_2(y_true, y_pred, epsilon=1e-6):
    intersection = K.sum(K.abs(y_true[:,:,:,:,2] * y_pred[:,:,:,:,2]))
    return (2. * intersection) / (K.sum(K.square(y_true[:,:,:,:,2])) + K.sum(K.square(y_pred[:,:,:,2])) + epsilon)

def dice_coef_enhancing_2(y_true, y_pred, epsilon=1e-6):
    intersection = K.sum(K.abs(y_true[:,:,:,:,3] * y_pred[:,:,:,:,3]))
    return (2. * intersection) / (K.sum(K.square(y_true[:,:,:,:,3])) + K.sum(K.square(y_pred[:,:,:,3])) + epsilon)


# Computing Precision 
def precision_2(y_true, y_pred):
        true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
        predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
        precision = true_positives / (predicted_positives + K.epsilon())
        return precision

    
# Computing Sensitivity      
def sensitivity_2(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    return true_positives / (possible_positives + K.epsilon())


# Computing Specificity
def specificity_2(y_true, y_pred):
    true_negatives = K.sum(K.round(K.clip((1-y_true) * (1-y_pred), 0, 1)))
    possible_negatives = K.sum(K.round(K.clip(1-y_true, 0, 1)))
    return true_negatives / (possible_negatives + K.epsilon())

# %%
model_2 = simple_unet_model(IMG_HEIGHT=128, 
                          IMG_WIDTH=128, 
                          IMG_DEPTH=128, 
                          IMG_CHANNELS=3, 
                          num_classes=4)
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 128, 128, 1  0           []
#                                 28, 3)]
#
#  conv3d_19 (Conv3D)             (None, 128, 128, 12  1312        ['input_2[0][0]']
#                                 8, 16)
#
#  dropout_9 (Dropout)            (None, 128, 128, 12  0           ['conv3d_19[0][0]']
#                                 8, 16)
#
#  conv3d_20 (Conv3D)             (None, 128, 128, 12  6928        ['dropout_9[0][0]']
#                                 8, 16)
#
#  max_pooling3d_4 (MaxPooling3D)  (None, 64, 64, 64,   0          ['conv3d_20[0][0]']
#                                 16)
#
#  conv3d_21 (Conv3D)             (None, 64, 64, 64,   13856       ['max_pooling3d_4[0][0]']
#                                 32)
#
#  dropout_10 (Dropout)           (None, 64, 64, 64,   0           ['conv3d_21[0][0]']
#                                 32)
#
#  conv3d_22 (Conv3D)             (None, 64, 64, 64,   27680       ['dropout_10[0][0]']
#                                 32)
#
#  max_pooling3d_5 (MaxPooling3D)  (None, 32, 32, 32,   0          ['conv3d_22[0][0]']
#                                 32)
#
#  conv3d_23 (Conv3D)             (None, 32, 32, 32,   55360       ['max_pooling3d_5[0][0]']
#                                 64)
#
#  dropout_11 (Dropout)           (None, 32, 32, 32,   0           ['conv3d_23[0][0]']
#                                 64)
#
#  conv3d_24 (Conv3D)             (None, 32, 32, 32,   110656      ['dropout_11[0][0]']
#                                 64)
#
#  max_pooling3d_6 (MaxPooling3D)  (None, 16, 16, 16,   0          ['conv3d_24[0][0]']
#                                 64)
#
#  conv3d_25 (Conv3D)             (None, 16, 16, 16,   221312      ['max_pooling3d_6[0][0]']
#                                 128)
#
#  dropout_12 (Dropout)           (None, 16, 16, 16,   0           ['conv3d_25[0][0]']
#                                 128)
#
#  conv3d_26 (Conv3D)             (None, 16, 16, 16,   442496      ['dropout_12[0][0]']
#                                 128)
#
#  max_pooling3d_7 (MaxPooling3D)  (None, 8, 8, 8, 128  0          ['conv3d_26[0][0]']
#                                 )
#
#  conv3d_27 (Conv3D)             (None, 8, 8, 8, 256  884992      ['max_pooling3d_7[0][0]']
#                                 )
#
#  dropout_13 (Dropout)           (None, 8, 8, 8, 256  0           ['conv3d_27[0][0]']
#                                 )
#
#  conv3d_28 (Conv3D)             (None, 8, 8, 8, 256  1769728     ['dropout_13[0][0]']
#                                 )
#
#  conv3d_transpose_4 (Conv3DTran  (None, 16, 16, 16,   262272     ['conv3d_28[0][0]']
#  spose)                         128)
#
#  concatenate_4 (Concatenate)    (None, 16, 16, 16,   0           ['conv3d_transpose_4[0][0]',
#                                 256)                              'conv3d_26[0][0]']
#
#  conv3d_29 (Conv3D)             (None, 16, 16, 16,   884864      ['concatenate_4[0][0]']
#                                 128)
#
#  dropout_14 (Dropout)           (None, 16, 16, 16,   0           ['conv3d_29[0][0]']
#                                 128)
#
#  conv3d_30 (Conv3D)             (None, 16, 16, 16,   442496      ['dropout_14[0][0]']
#                                 128)
#
#  conv3d_transpose_5 (Conv3DTran  (None, 32, 32, 32,   65600      ['conv3d_30[0][0]']
#  spose)                         64)
#
#  concatenate_5 (Concatenate)    (None, 32, 32, 32,   0           ['conv3d_transpose_5[0][0]',
#                                 128)                              'conv3d_24[0][0]']
#
#  conv3d_31 (Conv3D)             (None, 32, 32, 32,   221248      ['concatenate_5[0][0]']
#                                 64)
#
#  dropout_15 (Dropout)           (None, 32, 32, 32,   0           ['conv3d_31[0][0]']
#                                 64)
#
#  conv3d_32 (Conv3D)             (None, 32, 32, 32,   110656      ['dropout_15[0][0]']
#                                 64)
#
#  conv3d_transpose_6 (Conv3DTran  (None, 64, 64, 64,   16416      ['conv3d_32[0][0]']
#  spose)                         32)
#
#  concatenate_6 (Concatenate)    (None, 64, 64, 64,   0           ['conv3d_transpose_6[0][0]',
#                                 64)                               'conv3d_22[0][0]']
#
#  conv3d_33 (Conv3D)             (None, 64, 64, 64,   55328       ['concatenate_6[0][0]']
#                                 32)
#
#  dropout_16 (Dropout)           (None, 64, 64, 64,   0           ['conv3d_33[0][0]']
#                                 32)
#
#  conv3d_34 (Conv3D)             (None, 64, 64, 64,   27680       ['dropout_16[0][0]']
#                                 32)
#
#  conv3d_transpose_7 (Conv3DTran  (None, 128, 128, 12  4112       ['conv3d_34[0][0]']
#  spose)                         8, 16)
#
#  concatenate_7 (Concatenate)    (None, 128, 128, 12  0           ['conv3d_transpose_7[0][0]',
#                                 8, 32)                            'conv3d_20[0][0]']
#
#  conv3d_35 (Conv3D)             (None, 128, 128, 12  13840       ['concatenate_7[0][0]']
#                                 8, 16)
#
#  dropout_17 (Dropout)           (None, 128, 128, 12  0           ['conv3d_35[0][0]']
#                                 8, 16)
#
#  conv3d_36 (Conv3D)             (None, 128, 128, 12  6928        ['dropout_17[0][0]']
#                                 8, 16)
#
#  conv3d_37 (Conv3D)             (None, 128, 128, 12  68          ['conv3d_36[0][0]']
#                                 8, 4)
#
# ==================================================================================================
# Total params: 5,645,828
# Trainable params: 5,645,828
# Non-trainable params: 0
# __________________________________________________________________________________________________
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model/model_to_dot to work.
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model/model_to_dot to work.

# %%
model_2.compile(loss="categorical_crossentropy", optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001), 
                metrics = ['accuracy',tf.keras.metrics.MeanIoU(num_classes=4), 
                           dice_coef_2, precision_2, sensitivity_2, specificity_2, dice_coef_necrotic_2, dice_coef_edema_2 ,dice_coef_enhancing_2])

# %%
from keras.callbacks import ModelCheckpoint, EarlyStopping, CSVLogger

# filepath="3D-UNet-2018-weights-improvement-{epoch:02d}-{val_accuracy:.3f}.hdf5" 

# checkpoint = ModelCheckpoint(filepath, monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')

# early_stop = EarlyStopping(monitor='val_loss',min_delta=0.001, patience=15, verbose=1, restore_best_weights=True)

# csv_logger = CSVLogger('training_2018_3D_UNet.log')

start_time = time.time()

history_2 =  model_2.fit(train_img_datagen,
                    epochs=400,
                    verbose = 1,
                    steps_per_epoch=steps_per_epoch,
                    # callbacks= [csv_logger, early_stop],
                    validation_data = val_img_datagen,
                    validation_steps=val_steps_per_epoch,
                    )

end_time = time.time()
runtime_seconds = end_time - start_time

# Convert runtime to hours, minutes, and seconds
hours = int(runtime_seconds // 3600)
minutes = int((runtime_seconds % 3600) // 60)
seconds = int(runtime_seconds % 60)

print(f"Runtime: {hours} hours, {minutes} minutes, {seconds} seconds")
# Out:
# Epoch 1/400
# 120/120 [==============================] - 137s 970ms/step - loss: 0.3878 - accuracy: 0.9236 - mean_io_u: 0.4014 - dice_coef_2: 0.2445 - precision_2: 0.9349 - sensitivity_2: 0.8599 - specificity_2: 0.9833 - dice_coef_necrotic_2: 0.0792 - dice_coef_edema_2: 0.0770 - dice_coef_enhancing_2: 0.0413 - val_loss: 0.3779 - val_accuracy: 0.9501 - val_mean_io_u: 0.3757 - val_dice_coef_2: 0.2540 - val_precision_2: 0.9729 - val_sensitivity_2: 0.7965 - val_specificity_2: 0.9926 - val_dice_coef_necrotic_2: 0.1793 - val_dice_coef_edema_2: 0.2654 - val_dice_coef_enhancing_2: 0.1542
# Epoch 2/400
# 120/120 [==============================] - 114s 955ms/step - loss: 0.2045 - accuracy: 0.9521 - mean_io_u: 0.4264 - dice_coef_2: 0.2905 - precision_2: 0.9583 - sensitivity_2: 0.9440 - specificity_2: 0.9863 - dice_coef_necrotic_2: 0.1114 - dice_coef_edema_2: 0.1541 - dice_coef_enhancing_2: 0.0533 - val_loss: 0.4182 - val_accuracy: 0.9501 - val_mean_io_u: 0.3750 - val_dice_coef_2: 0.2537 - val_precision_2: 0.9864 - val_sensitivity_2: 0.7326 - val_specificity_2: 0.9966 - val_dice_coef_necrotic_2: 0.2302 - val_dice_coef_edema_2: 0.3304 - val_dice_coef_enhancing_2: 0.1639
# Epoch 3/400
# 120/120 [==============================] - 114s 955ms/step - loss: 0.1846 - accuracy: 0.9522 - mean_io_u: 0.4368 - dice_coef_2: 0.3065 - precision_2: 0.9645 - sensitivity_2: 0.9445 - specificity_2: 0.9884 - dice_coef_necrotic_2: 0.1363 - dice_coef_edema_2: 0.1858 - dice_coef_enhancing_2: 0.0564 - val_loss: 0.2524 - val_accuracy: 0.9516 - val_mean_io_u: 0.3760 - val_dice_coef_2: 0.2902 - val_precision_2: 0.9800 - val_sensitivity_2: 0.8880 - val_specificity_2: 0.9940 - val_dice_coef_necrotic_2: 0.2218 - val_dice_coef_edema_2: 0.3065 - val_dice_coef_enhancing_2: 0.1261
# Epoch 4/400
# 120/120 [==============================] - 114s 955ms/step - loss: 0.1710 - accuracy: 0.9526 - mean_io_u: 0.4382 - dice_coef_2: 0.3197 - precision_2: 0.9682 - sensitivity_2: 0.9442 - specificity_2: 0.9896 - dice_coef_necrotic_2: 0.1579 - dice_coef_edema_2: 0.2119 - dice_coef_enhancing_2: 0.0634 - val_loss: 0.1981 - val_accuracy: 0.9531 - val_mean_io_u: 0.3780 - val_dice_coef_2: 0.3099 - val_precision_2: 0.9773 - val_sensitivity_2: 0.9191 - val_specificity_2: 0.9929 - val_dice_coef_necrotic_2: 0.2120 - val_dice_coef_edema_2: 0.2914 - val_dice_coef_enhancing_2: 0.1057
# Epoch 5/400
# 120/120 [==============================] - 114s 954ms/step - loss: 0.1635 - accuracy: 0.9534 - mean_io_u: 0.4405 - dice_coef_2: 0.3280 - precision_2: 0.9699 - sensitivity_2: 0.9448 - specificity_2: 0.9902 - dice_coef_necrotic_2: 0.1711 - dice_coef_edema_2: 0.2271 - dice_coef_enhancing_2: 0.0673 - val_loss: 0.1850 - val_accuracy: 0.9535 - val_mean_io_u: 0.3793 - val_dice_coef_2: 0.3177 - val_precision_2: 0.9780 - val_sensitivity_2: 0.9240 - val_specificity_2: 0.9931 - val_dice_coef_necrotic_2: 0.2184 - val_dice_coef_edema_2: 0.3023 - val_dice_coef_enhancing_2: 0.1041
# Epoch 6/400
# 120/120 [==============================] - 114s 955ms/step - loss: 0.1533 - accuracy: 0.9551 - mean_io_u: 0.4419 - dice_coef_2: 0.3389 - precision_2: 0.9723 - sensitivity_2: 0.9451 - specificity_2: 0.9910 - dice_coef_necrotic_2: 0.1882 - dice_coef_edema_2: 0.2479 - dice_coef_enhancing_2: 0.0745 - val_loss: 0.1612 - val_accuracy: 0.9541 - val_mean_io_u: 0.3879 - val_dice_coef_2: 0.3334 - val_precision_2: 0.9780 - val_sensitivity_2: 0.9349 - val_specificity_2: 0.9930 - val_dice_coef_necrotic_2: 0.2248 - val_dice_coef_edema_2: 0.3148 - val_dice_coef_enhancing_2: 0.0990
# Epoch 7/400
# 120/120 [==============================] - 114s 955ms/step - loss: 0.1424 - accuracy: 0.9570 - mean_io_u: 0.4617 - dice_coef_2: 0.3524 - precision_2: 0.9751 - sensitivity_2: 0.9451 - specificity_2: 0.9919 - dice_coef_necrotic_2: 0.2064 - dice_coef_edema_2: 0.2797 - dice_coef_enhancing_2: 0.0832 - val_loss: 0.1455 - val_accuracy: 0.9561 - val_mean_io_u: 0.3885 - val_dice_coef_2: 0.3489 - val_precision_2: 0.9806 - val_sensitivity_2: 0.9388 - val_specificity_2: 0.9938 - val_dice_coef_necrotic_2: 0.2394 - val_dice_coef_edema_2: 0.3547 - val_dice_coef_enhancing_2: 0.1040
# Epoch 8/400
# 120/120 [==============================] - 114s 955ms/step - loss: 0.1272 - accuracy: 0.9594 - mean_io_u: 0.4822 - dice_coef_2: 0.3712 - precision_2: 0.9790 - sensitivity_2: 0.9451 - specificity_2: 0.9932 - dice_coef_necrotic_2: 0.2232 - dice_coef_edema_2: 0.3409 - dice_coef_enhancing_2: 0.0948 - val_loss: 0.1354 - val_accuracy: 0.9607 - val_mean_io_u: 0.3784 - val_dice_coef_2: 0.3635 - val_precision_2: 0.9852 - val_sensitivity_2: 0.9364 - val_specificity_2: 0.9953 - val_dice_coef_necrotic_2: 0.2573 - val_dice_coef_edema_2: 0.4345 - val_dice_coef_enhancing_2: 0.1107
# Epoch 9/400
# 120/120 [==============================] - 114s 955ms/step - loss: 0.1164 - accuracy: 0.9618 - mean_io_u: 0.4860 - dice_coef_2: 0.3883 - precision_2: 0.9800 - sensitivity_2: 0.9461 - specificity_2: 0.9936 - dice_coef_necrotic_2: 0.2121 - dice_coef_edema_2: 0.4443 - dice_coef_enhancing_2: 0.1126 - val_loss: 0.1236 - val_accuracy: 0.9634 - val_mean_io_u: 0.3888 - val_dice_coef_2: 0.3835 - val_precision_2: 0.9862 - val_sensitivity_2: 0.9373 - val_specificity_2: 0.9956 - val_dice_coef_necrotic_2: 0.2718 - val_dice_coef_edema_2: 0.4698 - val_dice_coef_enhancing_2: 0.1223
# Epoch 10/400
# 120/120 [==============================] - 114s 954ms/step - loss: 0.1068 - accuracy: 0.9632 - mean_io_u: 0.5064 - dice_coef_2: 0.4048 - precision_2: 0.9807 - sensitivity_2: 0.9485 - specificity_2: 0.9938 - dice_coef_necrotic_2: 0.2308 - dice_coef_edema_2: 0.4898 - dice_coef_enhancing_2: 0.1292 - val_loss: 0.1116 - val_accuracy: 0.9652 - val_mean_io_u: 0.4178 - val_dice_coef_2: 0.4071 - val_precision_2: 0.9861 - val_sensitivity_2: 0.9411 - val_specificity_2: 0.9956 - val_dice_coef_necrotic_2: 0.2783 - val_dice_coef_edema_2: 0.5001 - val_dice_coef_enhancing_2: 0.1287
# Epoch 11/400
# 120/120 [==============================] - 115s 955ms/step - loss: 0.0993 - accuracy: 0.9644 - mean_io_u: 0.5241 - dice_coef_2: 0.4180 - precision_2: 0.9809 - sensitivity_2: 0.9508 - specificity_2: 0.9938 - dice_coef_necrotic_2: 0.2399 - dice_coef_edema_2: 0.5291 - dice_coef_enhancing_2: 0.1491 - val_loss: 0.1062 - val_accuracy: 0.9649 - val_mean_io_u: 0.4704 - val_dice_coef_2: 0.4201 - val_precision_2: 0.9869 - val_sensitivity_2: 0.9423 - val_specificity_2: 0.9958 - val_dice_coef_necrotic_2: 0.2924 - val_dice_coef_edema_2: 0.5223 - val_dice_coef_enhancing_2: 0.1417
# Epoch 12/400
# 120/120 [==============================] - 114s 955ms/step - loss: 0.0946 - accuracy: 0.9651 - mean_io_u: 0.5521 - dice_coef_2: 0.4275 - precision_2: 0.9812 - sensitivity_2: 0.9521 - specificity_2: 0.9939 - dice_coef_necrotic_2: 0.2490 - dice_coef_edema_2: 0.5490 - dice_coef_enhancing_2: 0.1672 - val_loss: 0.1091 - val_accuracy: 0.9634 - val_mean_io_u: 0.4281 - val_dice_coef_2: 0.4166 - val_precision_2: 0.9887 - val_sensitivity_2: 0.9388 - val_specificity_2: 0.9964 - val_dice_coef_necrotic_2: 0.3084 - val_dice_coef_edema_2: 0.5545 - val_dice_coef_enhancing_2: 0.1637
# Epoch 13/400
# 120/120 [==============================] - 114s 954ms/step - loss: 0.0924 - accuracy: 0.9658 - mean_io_u: 0.5521 - dice_coef_2: 0.4323 - precision_2: 0.9811 - sensitivity_2: 0.9533 - specificity_2: 0.9939 - dice_coef_necrotic_2: 0.2518 - dice_coef_edema_2: 0.5594 - dice_coef_enhancing_2: 0.1768 - val_loss: 0.1163 - val_accuracy: 0.9619 - val_mean_io_u: 0.4513 - val_dice_coef_2: 0.4032 - val_precision_2: 0.9897 - val_sensitivity_2: 0.9348 - val_specificity_2: 0.9968 - val_dice_coef_necrotic_2: 0.3172 - val_dice_coef_edema_2: 0.5834 - val_dice_coef_enhancing_2: 0.1743
# Epoch 14/400
# 120/120 [==============================] - 114s 955ms/step - loss: 0.0910 - accuracy: 0.9663 - mean_io_u: 0.5746 - dice_coef_2: 0.4354 - precision_2: 0.9810 - sensitivity_2: 0.9540 - specificity_2: 0.9939 - dice_coef_necrotic_2: 0.2550 - dice_coef_edema_2: 0.5670 - dice_coef_enhancing_2: 0.1831 - val_loss: 0.1126 - val_accuracy: 0.9642 - val_mean_io_u: 0.4708 - val_dice_coef_2: 0.4155 - val_precision_2: 0.9848 - val_sensitivity_2: 0.9442 - val_specificity_2: 0.9951 - val_dice_coef_necrotic_2: 0.2877 - val_dice_coef_edema_2: 0.5325 - val_dice_coef_enhancing_2: 0.1553
# Epoch 15/400
# 120/120 [==============================] - 114s 955ms/step - loss: 0.0880 - accuracy: 0.9669 - mean_io_u: 0.6001 - dice_coef_2: 0.4414 - precision_2: 0.9814 - sensitivity_2: 0.9548 - specificity_2: 0.9940 - dice_coef_necrotic_2: 0.2582 - dice_coef_edema_2: 0.5834 - dice_coef_enhancing_2: 0.1946 - val_loss: 0.1347 - val_accuracy: 0.9592 - val_mean_io_u: 0.4727 - val_dice_coef_2: 0.3901 - val_precision_2: 0.9930 - val_sensitivity_2: 0.9239 - val_specificity_2: 0.9978 - val_dice_coef_necrotic_2: 0.3101 - val_dice_coef_edema_2: 0.6090 - val_dice_coef_enhancing_2: 0.2213
# Epoch 16/400
# 120/120 [==============================] - 114s 955ms/step - loss: 0.0916 - accuracy: 0.9668 - mean_io_u: 0.5087 - dice_coef_2: 0.4383 - precision_2: 0.9810 - sensitivity_2: 0.9548 - specificity_2: 0.9938 - dice_coef_necrotic_2: 0.2553 - dice_coef_edema_2: 0.5795 - dice_coef_enhancing_2: 0.1941 - val_loss: 0.1328 - val_accuracy: 0.9577 - val_mean_io_u: 0.4280 - val_dice_coef_2: 0.3948 - val_precision_2: 0.9935 - val_sensitivity_2: 0.9233 - val_specificity_2: 0.9980 - val_dice_coef_necrotic_2: 0.3199 - val_dice_coef_edema_2: 0.6410 - val_dice_coef_enhancing_2: 0.2242
# Epoch 17/400
# 120/120 [==============================] - 115s 955ms/step - loss: 0.0821 - accuracy: 0.9685 - mean_io_u: 0.5878 - dice_coef_2: 0.4521 - precision_2: 0.9817 - sensitivity_2: 0.9574 - specificity_2: 0.9941 - dice_coef_necrotic_2: 0.2615 - dice_coef_edema_2: 0.6115 - dice_coef_enhancing_2: 0.2126 - val_loss: 0.1222 - val_accuracy: 0.9605 - val_mean_io_u: 0.4823 - val_dice_coef_2: 0.4087 - val_precision_2: 0.9910 - val_sensitivity_2: 0.9316 - val_specificity_2: 0.9972 - val_dice_coef_necrotic_2: 0.3127 - val_dice_coef_edema_2: 0.6649 - val_dice_coef_enhancing_2: 0.2437
# Epoch 18/400
# 120/120 [==============================] - 114s 955ms/step - loss: 0.0781 - accuracy: 0.9694 - mean_io_u: 0.6108 - dice_coef_2: 0.4622 - precision_2: 0.9814 - sensitivity_2: 0.9594 - specificity_2: 0.9940 - dice_coef_necrotic_2: 0.2649 - dice_coef_edema_2: 0.6354 - dice_coef_enhancing_2: 0.2329 - val_loss: 0.1140 - val_accuracy: 0.9611 - val_mean_io_u: 0.4882 - val_dice_coef_2: 0.4239 - val_precision_2: 0.9892 - val_sensitivity_2: 0.9365 - val_specificity_2: 0.9966 - val_dice_coef_necrotic_2: 0.3106 - val_dice_coef_edema_2: 0.6711 - val_dice_coef_enhancing_2: 0.2658
# Epoch 19/400
# 120/120 [==============================] - 114s 955ms/step - loss: 0.0759 - accuracy: 0.9701 - mean_io_u: 0.6116 - dice_coef_2: 0.4699 - precision_2: 0.9814 - sensitivity_2: 0.9606 - specificity_2: 0.9939 - dice_coef_necrotic_2: 0.2694 - dice_coef_edema_2: 0.6465 - dice_coef_enhancing_2: 0.2525 - val_loss: 0.1205 - val_accuracy: 0.9581 - val_mean_io_u: 0.5027 - val_dice_coef_2: 0.4244 - val_precision_2: 0.9884 - val_sensitivity_2: 0.9331 - val_specificity_2: 0.9964 - val_dice_coef_necrotic_2: 0.3113 - val_dice_coef_edema_2: 0.6666 - val_dice_coef_enhancing_2: 0.3075
# Epoch 20/400
# 120/120 [==============================] - 114s 955ms/step - loss: 0.0733 - accuracy: 0.9708 - mean_io_u: 0.6357 - dice_coef_2: 0.4775 - precision_2: 0.9815 - sensitivity_2: 0.9618 - specificity_2: 0.9940 - dice_coef_necrotic_2: 0.2738 - dice_coef_edema_2: 0.6584 - dice_coef_enhancing_2: 0.2717 - val_loss: 0.1159 - val_accuracy: 0.9596 - val_mean_io_u: 0.5203 - val_dice_coef_2: 0.4309 - val_precision_2: 0.9877 - val_sensitivity_2: 0.9363 - val_specificity_2: 0.9961 - val_dice_coef_necrotic_2: 0.3114 - val_dice_coef_edema_2: 0.6711 - val_dice_coef_enhancing_2: 0.3331
# Epoch 21/400
# 120/120 [==============================] - 114s 955ms/step - loss: 0.0713 - accuracy: 0.9715 - mean_io_u: 0.6450 - dice_coef_2: 0.4853 - precision_2: 0.9815 - sensitivity_2: 0.9631 - specificity_2: 0.9940 - dice_coef_necrotic_2: 0.2774 - dice_coef_edema_2: 0.6746 - dice_coef_enhancing_2: 0.2906 - val_loss: 0.1249 - val_accuracy: 0.9561 - val_mean_io_u: 0.5148 - val_dice_coef_2: 0.4275 - val_precision_2: 0.9849 - val_sensitivity_2: 0.9335 - val_specificity_2: 0.9953 - val_dice_coef_necrotic_2: 0.3123 - val_dice_coef_edema_2: 0.6721 - val_dice_coef_enhancing_2: 0.3630
# Epoch 22/400
# 120/120 [==============================] - 114s 955ms/step - loss: 0.0704 - accuracy: 0.9719 - mean_io_u: 0.6539 - dice_coef_2: 0.4909 - precision_2: 0.9815 - sensitivity_2: 0.9638 - specificity_2: 0.9939 - dice_coef_necrotic_2: 0.2800 - dice_coef_edema_2: 0.6847 - dice_coef_enhancing_2: 0.3058 - val_loss: 0.1291 - val_accuracy: 0.9551 - val_mean_io_u: 0.4882 - val_dice_coef_2: 0.4265 - val_precision_2: 0.9830 - val_sensitivity_2: 0.9339 - val_specificity_2: 0.9947 - val_dice_coef_necrotic_2: 0.3078 - val_dice_coef_edema_2: 0.6722 - val_dice_coef_enhancing_2: 0.3855
# Epoch 23/400
# 120/120 [==============================] - 115s 955ms/step - loss: 0.0688 - accuracy: 0.9725 - mean_io_u: 0.6454 - dice_coef_2: 0.4979 - precision_2: 0.9817 - sensitivity_2: 0.9648 - specificity_2: 0.9940 - dice_coef_necrotic_2: 0.2829 - dice_coef_edema_2: 0.6978 - dice_coef_enhancing_2: 0.3237 - val_loss: 0.1295 - val_accuracy: 0.9547 - val_mean_io_u: 0.5080 - val_dice_coef_2: 0.4319 - val_precision_2: 0.9779 - val_sensitivity_2: 0.9377 - val_specificity_2: 0.9930 - val_dice_coef_necrotic_2: 0.2800 - val_dice_coef_edema_2: 0.7330 - val_dice_coef_enhancing_2: 0.3897
# Epoch 24/400
# 120/120 [==============================] - 115s 955ms/step - loss: 0.0669 - accuracy: 0.9733 - mean_io_u: 0.6681 - dice_coef_2: 0.5067 - precision_2: 0.9821 - sensitivity_2: 0.9660 - specificity_2: 0.9942 - dice_coef_necrotic_2: 0.2861 - dice_coef_edema_2: 0.7167 - dice_coef_enhancing_2: 0.3454 - val_loss: 0.1329 - val_accuracy: 0.9534 - val_mean_io_u: 0.5071 - val_dice_coef_2: 0.4363 - val_precision_2: 0.9749 - val_sensitivity_2: 0.9382 - val_specificity_2: 0.9920 - val_dice_coef_necrotic_2: 0.2710 - val_dice_coef_edema_2: 0.7635 - val_dice_coef_enhancing_2: 0.4013
# Epoch 25/400
# 120/120 [==============================] - 115s 955ms/step - loss: 0.0661 - accuracy: 0.9737 - mean_io_u: 0.6717 - dice_coef_2: 0.5132 - precision_2: 0.9823 - sensitivity_2: 0.9666 - specificity_2: 0.9942 - dice_coef_necrotic_2: 0.2930 - dice_coef_edema_2: 0.7320 - dice_coef_enhancing_2: 0.3602 - val_loss: 0.1014 - val_accuracy: 0.9650 - val_mean_io_u: 0.5087 - val_dice_coef_2: 0.4616 - val_precision_2: 0.9800 - val_sensitivity_2: 0.9534 - val_specificity_2: 0.9935 - val_dice_coef_necrotic_2: 0.2740 - val_dice_coef_edema_2: 0.7614 - val_dice_coef_enhancing_2: 0.3688
# Epoch 26/400
# 120/120 [==============================] - 115s 955ms/step - loss: 0.0644 - accuracy: 0.9743 - mean_io_u: 0.6704 - dice_coef_2: 0.5185 - precision_2: 0.9827 - sensitivity_2: 0.9673 - specificity_2: 0.9943 - dice_coef_necrotic_2: 0.2958 - dice_coef_edema_2: 0.7421 - dice_coef_enhancing_2: 0.3714 - val_loss: 0.1249 - val_accuracy: 0.9561 - val_mean_io_u: 0.5151 - val_dice_coef_2: 0.4498 - val_precision_2: 0.9736 - val_sensitivity_2: 0.9443 - val_specificity_2: 0.9915 - val_dice_coef_necrotic_2: 0.2643 - val_dice_coef_edema_2: 0.8436 - val_dice_coef_enhancing_2: 0.3973
# Epoch 27/400
# 120/120 [==============================] - 115s 955ms/step - loss: 0.0625 - accuracy: 0.9750 - mean_io_u: 0.6942 - dice_coef_2: 0.5281 - precision_2: 0.9829 - sensitivity_2: 0.9685 - specificity_2: 0.9944 - dice_coef_necrotic_2: 0.3018 - dice_coef_edema_2: 0.7666 - dice_coef_enhancing_2: 0.3847 - val_loss: 0.1188 - val_accuracy: 0.9577 - val_mean_io_u: 0.5256 - val_dice_coef_2: 0.4642 - val_precision_2: 0.9736 - val_sensitivity_2: 0.9472 - val_specificity_2: 0.9915 - val_dice_coef_necrotic_2: 0.2674 - val_dice_coef_edema_2: 0.8537 - val_dice_coef_enhancing_2: 0.4219
# Epoch 28/400
# 120/120 [==============================] - 115s 955ms/step - loss: 0.0615 - accuracy: 0.9755 - mean_io_u: 0.7021 - dice_coef_2: 0.5334 - precision_2: 0.9831 - sensitivity_2: 0.9690 - specificity_2: 0.9945 - dice_coef_necrotic_2: 0.3095 - dice_coef_edema_2: 0.7769 - dice_coef_enhancing_2: 0.3952 - val_loss: 0.1019 - val_accuracy: 0.9638 - val_mean_io_u: 0.5497 - val_dice_coef_2: 0.4824 - val_precision_2: 0.9770 - val_sensitivity_2: 0.9547 - val_specificity_2: 0.9925 - val_dice_coef_necrotic_2: 0.2701 - val_dice_coef_edema_2: 0.8638 - val_dice_coef_enhancing_2: 0.4129
# Epoch 29/400
# 120/120 [==============================] - 115s 955ms/step - loss: 0.0614 - accuracy: 0.9757 - mean_io_u: 0.6935 - dice_coef_2: 0.5362 - precision_2: 0.9832 - sensitivity_2: 0.9694 - specificity_2: 0.9945 - dice_coef_necrotic_2: 0.3119 - dice_coef_edema_2: 0.7819 - dice_coef_enhancing_2: 0.4009 - val_loss: 0.0971 - val_accuracy: 0.9660 - val_mean_io_u: 0.5623 - val_dice_coef_2: 0.4895 - val_precision_2: 0.9769 - val_sensitivity_2: 0.9584 - val_specificity_2: 0.9925 - val_dice_coef_necrotic_2: 0.2299 - val_dice_coef_edema_2: 0.9090 - val_dice_coef_enhancing_2: 0.4299
# Epoch 30/400
# 120/120 [==============================] - 115s 955ms/step - loss: 0.0628 - accuracy: 0.9758 - mean_io_u: 0.6844 - dice_coef_2: 0.5374 - precision_2: 0.9831 - sensitivity_2: 0.9697 - specificity_2: 0.9944 - dice_coef_necrotic_2: 0.3194 - dice_coef_edema_2: 0.7872 - dice_coef_enhancing_2: 0.4035 - val_loss: 0.1347 - val_accuracy: 0.9536 - val_mean_io_u: 0.4035 - val_dice_coef_2: 0.4433 - val_precision_2: 0.9712 - val_sensitivity_2: 0.9425 - val_specificity_2: 0.9907 - val_dice_coef_necrotic_2: 0.2105 - val_dice_coef_edema_2: 0.9004 - val_dice_coef_enhancing_2: 0.4103
# Epoch 31/400
# 120/120 [==============================] - 114s 955ms/step - loss: 0.0783 - accuracy: 0.9723 - mean_io_u: 0.5494 - dice_coef_2: 0.5021 - precision_2: 0.9807 - sensitivity_2: 0.9652 - specificity_2: 0.9937 - dice_coef_necrotic_2: 0.2940 - dice_coef_edema_2: 0.7237 - dice_coef_enhancing_2: 0.3311 - val_loss: 0.0928 - val_accuracy: 0.9700 - val_mean_io_u: 0.4577 - val_dice_coef_2: 0.4600 - val_precision_2: 0.9792 - val_sensitivity_2: 0.9620 - val_specificity_2: 0.9932 - val_dice_coef_necrotic_2: 0.1958 - val_dice_coef_edema_2: 0.8317 - val_dice_coef_enhancing_2: 0.2769
# Epoch 32/400
# 120/120 [==============================] - 114s 955ms/step - loss: 0.0661 - accuracy: 0.9749 - mean_io_u: 0.6415 - dice_coef_2: 0.5196 - precision_2: 0.9832 - sensitivity_2: 0.9677 - specificity_2: 0.9945 - dice_coef_necrotic_2: 0.3222 - dice_coef_edema_2: 0.7396 - dice_coef_enhancing_2: 0.3600 - val_loss: 0.0929 - val_accuracy: 0.9667 - val_mean_io_u: 0.5535 - val_dice_coef_2: 0.4937 - val_precision_2: 0.9770 - val_sensitivity_2: 0.9593 - val_specificity_2: 0.9925 - val_dice_coef_necrotic_2: 0.2514 - val_dice_coef_edema_2: 0.9587 - val_dice_coef_enhancing_2: 0.4135
# Epoch 33/400
# 120/120 [==============================] - 114s 955ms/step - loss: 0.0625 - accuracy: 0.9759 - mean_io_u: 0.6767 - dice_coef_2: 0.5377 - precision_2: 0.9833 - sensitivity_2: 0.9698 - specificity_2: 0.9945 - dice_coef_necrotic_2: 0.3214 - dice_coef_edema_2: 0.7854 - dice_coef_enhancing_2: 0.4067 - val_loss: 0.1074 - val_accuracy: 0.9634 - val_mean_io_u: 0.5507 - val_dice_coef_2: 0.4753 - val_precision_2: 0.9766 - val_sensitivity_2: 0.9535 - val_specificity_2: 0.9924 - val_dice_coef_necrotic_2: 0.2734 - val_dice_coef_edema_2: 0.8783 - val_dice_coef_enhancing_2: 0.4008
# Epoch 34/400
# 120/120 [==============================] - 114s 955ms/step - loss: 0.0629 - accuracy: 0.9758 - mean_io_u: 0.7031 - dice_coef_2: 0.5371 - precision_2: 0.9832 - sensitivity_2: 0.9695 - specificity_2: 0.9945 - dice_coef_necrotic_2: 0.3229 - dice_coef_edema_2: 0.7839 - dice_coef_enhancing_2: 0.3979 - val_loss: 0.0877 - val_accuracy: 0.9698 - val_mean_io_u: 0.5674 - val_dice_coef_2: 0.4994 - val_precision_2: 0.9774 - val_sensitivity_2: 0.9638 - val_specificity_2: 0.9926 - val_dice_coef_necrotic_2: 0.2332 - val_dice_coef_edema_2: 0.9824 - val_dice_coef_enhancing_2: 0.3677
# Epoch 35/400
# 120/120 [==============================] - 114s 955ms/step - loss: 0.0611 - accuracy: 0.9764 - mean_io_u: 0.7062 - dice_coef_2: 0.5437 - precision_2: 0.9834 - sensitivity_2: 0.9705 - specificity_2: 0.9946 - dice_coef_necrotic_2: 0.3260 - dice_coef_edema_2: 0.8028 - dice_coef_enhancing_2: 0.4063 - val_loss: 0.0846 - val_accuracy: 0.9695 - val_mean_io_u: 0.6215 - val_dice_coef_2: 0.5122 - val_precision_2: 0.9790 - val_sensitivity_2: 0.9625 - val_specificity_2: 0.9931 - val_dice_coef_necrotic_2: 0.2658 - val_dice_coef_edema_2: 0.9583 - val_dice_coef_enhancing_2: 0.4299
# Epoch 36/400
# 120/120 [==============================] - 115s 955ms/step - loss: 0.0571 - accuracy: 0.9775 - mean_io_u: 0.7258 - dice_coef_2: 0.5581 - precision_2: 0.9839 - sensitivity_2: 0.9721 - specificity_2: 0.9947 - dice_coef_necrotic_2: 0.3461 - dice_coef_edema_2: 0.8240 - dice_coef_enhancing_2: 0.4341 - val_loss: 0.0839 - val_accuracy: 0.9692 - val_mean_io_u: 0.5977 - val_dice_coef_2: 0.5217 - val_precision_2: 0.9776 - val_sensitivity_2: 0.9634 - val_specificity_2: 0.9926 - val_dice_coef_necrotic_2: 0.2724 - val_dice_coef_edema_2: 0.9905 - val_dice_coef_enhancing_2: 0.4256
# Epoch 37/400
# 120/120 [==============================] - 115s 955ms/step - loss: 0.0562 - accuracy: 0.9778 - mean_io_u: 0.7328 - dice_coef_2: 0.5642 - precision_2: 0.9838 - sensitivity_2: 0.9727 - specificity_2: 0.9947 - dice_coef_necrotic_2: 0.3522 - dice_coef_edema_2: 0.8406 - dice_coef_enhancing_2: 0.4419 - val_loss: 0.0807 - val_accuracy: 0.9706 - val_mean_io_u: 0.6169 - val_dice_coef_2: 0.5249 - val_precision_2: 0.9791 - val_sensitivity_2: 0.9646 - val_specificity_2: 0.9931 - val_dice_coef_necrotic_2: 0.2750 - val_dice_coef_edema_2: 0.9596 - val_dice_coef_enhancing_2: 0.4308
# Epoch 38/400
# 120/120 [==============================] - 114s 955ms/step - loss: 0.0544 - accuracy: 0.9786 - mean_io_u: 0.7393 - dice_coef_2: 0.5721 - precision_2: 0.9842 - sensitivity_2: 0.9738 - specificity_2: 0.9948 - dice_coef_necrotic_2: 0.3586 - dice_coef_edema_2: 0.8606 - dice_coef_enhancing_2: 0.4543 - val_loss: 0.0804 - val_accuracy: 0.9708 - val_mean_io_u: 0.6522 - val_dice_coef_2: 0.5327 - val_precision_2: 0.9790 - val_sensitivity_2: 0.9651 - val_specificity_2: 0.9931 - val_dice_coef_necrotic_2: 0.2830 - val_dice_coef_edema_2: 0.9463 - val_dice_coef_enhancing_2: 0.4532
# Epoch 39/400
# 120/120 [==============================] - 117s 978ms/step - loss: 0.0538 - accuracy: 0.9787 - mean_io_u: 0.7524 - dice_coef_2: 0.5767 - precision_2: 0.9842 - sensitivity_2: 0.9741 - specificity_2: 0.9948 - dice_coef_necrotic_2: 0.3685 - dice_coef_edema_2: 0.8644 - dice_coef_enhancing_2: 0.4622 - val_loss: 0.0766 - val_accuracy: 0.9722 - val_mean_io_u: 0.6629 - val_dice_coef_2: 0.5409 - val_precision_2: 0.9793 - val_sensitivity_2: 0.9671 - val_specificity_2: 0.9932 - val_dice_coef_necrotic_2: 0.2771 - val_dice_coef_edema_2: 0.9956 - val_dice_coef_enhancing_2: 0.4443
# Epoch 40/400
# 120/120 [==============================] - 115s 956ms/step - loss: 0.0524 - accuracy: 0.9794 - mean_io_u: 0.7624 - dice_coef_2: 0.5841 - precision_2: 0.9845 - sensitivity_2: 0.9750 - specificity_2: 0.9949 - dice_coef_necrotic_2: 0.3787 - dice_coef_edema_2: 0.8813 - dice_coef_enhancing_2: 0.4703 - val_loss: 0.0798 - val_accuracy: 0.9716 - val_mean_io_u: 0.6953 - val_dice_coef_2: 0.5400 - val_precision_2: 0.9797 - val_sensitivity_2: 0.9660 - val_specificity_2: 0.9933 - val_dice_coef_necrotic_2: 0.2967 - val_dice_coef_edema_2: 0.9243 - val_dice_coef_enhancing_2: 0.4705
# Epoch 41/400
# 120/120 [==============================] - 114s 955ms/step - loss: 0.0519 - accuracy: 0.9796 - mean_io_u: 0.7669 - dice_coef_2: 0.5891 - precision_2: 0.9845 - sensitivity_2: 0.9754 - specificity_2: 0.9949 - dice_coef_necrotic_2: 0.3888 - dice_coef_edema_2: 0.8903 - dice_coef_enhancing_2: 0.4773 - val_loss: 0.0782 - val_accuracy: 0.9716 - val_mean_io_u: 0.6426 - val_dice_coef_2: 0.5379 - val_precision_2: 0.9794 - val_sensitivity_2: 0.9661 - val_specificity_2: 0.9932 - val_dice_coef_necrotic_2: 0.2875 - val_dice_coef_edema_2: 0.9868 - val_dice_coef_enhancing_2: 0.4634
# Epoch 42/400
# 120/120 [==============================] - 114s 955ms/step - loss: 0.0527 - accuracy: 0.9792 - mean_io_u: 0.7561 - dice_coef_2: 0.5860 - precision_2: 0.9843 - sensitivity_2: 0.9749 - specificity_2: 0.9948 - dice_coef_necrotic_2: 0.3891 - dice_coef_edema_2: 0.8749 - dice_coef_enhancing_2: 0.4738 - val_loss: 0.0846 - val_accuracy: 0.9691 - val_mean_io_u: 0.6556 - val_dice_coef_2: 0.5318 - val_precision_2: 0.9776 - val_sensitivity_2: 0.9632 - val_specificity_2: 0.9926 - val_dice_coef_necrotic_2: 0.3076 - val_dice_coef_edema_2: 0.9878 - val_dice_coef_enhancing_2: 0.4274
# Epoch 43/400
# 120/120 [==============================] - 114s 955ms/step - loss: 0.0541 - accuracy: 0.9791 - mean_io_u: 0.7466 - dice_coef_2: 0.5840 - precision_2: 0.9844 - sensitivity_2: 0.9747 - specificity_2: 0.9948 - dice_coef_necrotic_2: 0.3890 - dice_coef_edema_2: 0.8781 - dice_coef_enhancing_2: 0.4626 - val_loss: 0.0748 - val_accuracy: 0.9751 - val_mean_io_u: 0.6942 - val_dice_coef_2: 0.5498 - val_precision_2: 0.9815 - val_sensitivity_2: 0.9699 - val_specificity_2: 0.9939 - val_dice_coef_necrotic_2: 0.2896 - val_dice_coef_edema_2: 0.9230 - val_dice_coef_enhancing_2: 0.4323
# Epoch 44/400
# 120/120 [==============================] - 114s 955ms/step - loss: 0.0525 - accuracy: 0.9796 - mean_io_u: 0.7563 - dice_coef_2: 0.5884 - precision_2: 0.9848 - sensitivity_2: 0.9752 - specificity_2: 0.9950 - dice_coef_necrotic_2: 0.3971 - dice_coef_edema_2: 0.8815 - dice_coef_enhancing_2: 0.4752 - val_loss: 0.0764 - val_accuracy: 0.9732 - val_mean_io_u: 0.6310 - val_dice_coef_2: 0.5418 - val_precision_2: 0.9806 - val_sensitivity_2: 0.9674 - val_specificity_2: 0.9936 - val_dice_coef_necrotic_2: 0.3203 - val_dice_coef_edema_2: 0.9629 - val_dice_coef_enhancing_2: 0.4275
# Epoch 45/400
# 120/120 [==============================] - 114s 955ms/step - loss: 0.0561 - accuracy: 0.9784 - mean_io_u: 0.7568 - dice_coef_2: 0.5806 - precision_2: 0.9839 - sensitivity_2: 0.9738 - specificity_2: 0.9947 - dice_coef_necrotic_2: 0.3898 - dice_coef_edema_2: 0.8610 - dice_coef_enhancing_2: 0.4644 - val_loss: 0.0773 - val_accuracy: 0.9737 - val_mean_io_u: 0.6785 - val_dice_coef_2: 0.5230 - val_precision_2: 0.9839 - val_sensitivity_2: 0.9650 - val_specificity_2: 0.9948 - val_dice_coef_necrotic_2: 0.3269 - val_dice_coef_edema_2: 0.8057 - val_dice_coef_enhancing_2: 0.4466
# Epoch 46/400
# 120/120 [==============================] - 114s 955ms/step - loss: 0.0540 - accuracy: 0.9792 - mean_io_u: 0.7372 - dice_coef_2: 0.5813 - precision_2: 0.9847 - sensitivity_2: 0.9745 - specificity_2: 0.9949 - dice_coef_necrotic_2: 0.3924 - dice_coef_edema_2: 0.8697 - dice_coef_enhancing_2: 0.4605 - val_loss: 0.0715 - val_accuracy: 0.9749 - val_mean_io_u: 0.6575 - val_dice_coef_2: 0.5471 - val_precision_2: 0.9823 - val_sensitivity_2: 0.9688 - val_specificity_2: 0.9942 - val_dice_coef_necrotic_2: 0.3073 - val_dice_coef_edema_2: 0.9045 - val_dice_coef_enhancing_2: 0.4914
# Epoch 47/400
# 120/120 [==============================] - 114s 955ms/step - loss: 0.0532 - accuracy: 0.9792 - mean_io_u: 0.7547 - dice_coef_2: 0.5898 - precision_2: 0.9843 - sensitivity_2: 0.9748 - specificity_2: 0.9948 - dice_coef_necrotic_2: 0.3999 - dice_coef_edema_2: 0.8747 - dice_coef_enhancing_2: 0.4816 - val_loss: 0.0715 - val_accuracy: 0.9744 - val_mean_io_u: 0.7178 - val_dice_coef_2: 0.5498 - val_precision_2: 0.9828 - val_sensitivity_2: 0.9678 - val_specificity_2: 0.9944 - val_dice_coef_necrotic_2: 0.3725 - val_dice_coef_edema_2: 0.8565 - val_dice_coef_enhancing_2: 0.4805
# Epoch 48/400
# 120/120 [==============================] - 114s 955ms/step - loss: 0.0523 - accuracy: 0.9797 - mean_io_u: 0.7734 - dice_coef_2: 0.5924 - precision_2: 0.9848 - sensitivity_2: 0.9753 - specificity_2: 0.9950 - dice_coef_necrotic_2: 0.4007 - dice_coef_edema_2: 0.8891 - dice_coef_enhancing_2: 0.4834 - val_loss: 0.0753 - val_accuracy: 0.9732 - val_mean_io_u: 0.6547 - val_dice_coef_2: 0.5412 - val_precision_2: 0.9818 - val_sensitivity_2: 0.9666 - val_specificity_2: 0.9940 - val_dice_coef_necrotic_2: 0.3608 - val_dice_coef_edema_2: 0.8539 - val_dice_coef_enhancing_2: 0.4798
# Epoch 49/400
# 120/120 [==============================] - 114s 955ms/step - loss: 0.0528 - accuracy: 0.9794 - mean_io_u: 0.7705 - dice_coef_2: 0.5930 - precision_2: 0.9844 - sensitivity_2: 0.9751 - specificity_2: 0.9949 - dice_coef_necrotic_2: 0.4099 - dice_coef_edema_2: 0.8780 - dice_coef_enhancing_2: 0.4884 - val_loss: 0.0806 - val_accuracy: 0.9719 - val_mean_io_u: 0.6420 - val_dice_coef_2: 0.5326 - val_precision_2: 0.9815 - val_sensitivity_2: 0.9645 - val_specificity_2: 0.9940 - val_dice_coef_necrotic_2: 0.3706 - val_dice_coef_edema_2: 0.7894 - val_dice_coef_enhancing_2: 0.4881
# Epoch 50/400
# 120/120 [==============================] - 114s 955ms/step - loss: 0.0528 - accuracy: 0.9796 - mean_io_u: 0.7691 - dice_coef_2: 0.5942 - precision_2: 0.9845 - sensitivity_2: 0.9753 - specificity_2: 0.9949 - dice_coef_necrotic_2: 0.4021 - dice_coef_edema_2: 0.8925 - dice_coef_enhancing_2: 0.4915 - val_loss: 0.0799 - val_accuracy: 0.9731 - val_mean_io_u: 0.7240 - val_dice_coef_2: 0.5447 - val_precision_2: 0.9803 - val_sensitivity_2: 0.9674 - val_specificity_2: 0.9935 - val_dice_coef_necrotic_2: 0.3845 - val_dice_coef_edema_2: 0.6856 - val_dice_coef_enhancing_2: 0.4883
# Epoch 51/400
# 120/120 [==============================] - 114s 955ms/step - loss: 0.0516 - accuracy: 0.9800 - mean_io_u: 0.7627 - dice_coef_2: 0.6013 - precision_2: 0.9847 - sensitivity_2: 0.9760 - specificity_2: 0.9949 - dice_coef_necrotic_2: 0.4216 - dice_coef_edema_2: 0.8921 - dice_coef_enhancing_2: 0.4938 - val_loss: 0.0730 - val_accuracy: 0.9767 - val_mean_io_u: 0.7162 - val_dice_coef_2: 0.5684 - val_precision_2: 0.9830 - val_sensitivity_2: 0.9715 - val_specificity_2: 0.9944 - val_dice_coef_necrotic_2: 0.3825 - val_dice_coef_edema_2: 0.8265 - val_dice_coef_enhancing_2: 0.5003
# Epoch 52/400
# 120/120 [==============================] - 114s 955ms/step - loss: 0.0478 - accuracy: 0.9812 - mean_io_u: 0.7756 - dice_coef_2: 0.6175 - precision_2: 0.9853 - sensitivity_2: 0.9777 - specificity_2: 0.9952 - dice_coef_necrotic_2: 0.4402 - dice_coef_edema_2: 0.9410 - dice_coef_enhancing_2: 0.5104 - val_loss: 0.0724 - val_accuracy: 0.9763 - val_mean_io_u: 0.7210 - val_dice_coef_2: 0.5785 - val_precision_2: 0.9820 - val_sensitivity_2: 0.9719 - val_specificity_2: 0.9941 - val_dice_coef_necrotic_2: 0.3768 - val_dice_coef_edema_2: 0.9025 - val_dice_coef_enhancing_2: 0.4825
# Epoch 53/400
# 120/120 [==============================] - 114s 955ms/step - loss: 0.0452 - accuracy: 0.9823 - mean_io_u: 0.7826 - dice_coef_2: 0.6325 - precision_2: 0.9860 - sensitivity_2: 0.9793 - specificity_2: 0.9954 - dice_coef_necrotic_2: 0.4600 - dice_coef_edema_2: 0.9738 - dice_coef_enhancing_2: 0.5226 - val_loss: 0.0726 - val_accuracy: 0.9755 - val_mean_io_u: 0.6600 - val_dice_coef_2: 0.5782 - val_precision_2: 0.9811 - val_sensitivity_2: 0.9714 - val_specificity_2: 0.9938 - val_dice_coef_necrotic_2: 0.3745 - val_dice_coef_edema_2: 0.9447 - val_dice_coef_enhancing_2: 0.5127
# Epoch 54/400
# 120/120 [==============================] - 115s 955ms/step - loss: 0.0455 - accuracy: 0.9825 - mean_io_u: 0.7735 - dice_coef_2: 0.6354 - precision_2: 0.9861 - sensitivity_2: 0.9795 - specificity_2: 0.9954 - dice_coef_necrotic_2: 0.4772 - dice_coef_edema_2: 0.9766 - dice_coef_enhancing_2: 0.5130 - val_loss: 0.0706 - val_accuracy: 0.9763 - val_mean_io_u: 0.7015 - val_dice_coef_2: 0.5872 - val_precision_2: 0.9816 - val_sensitivity_2: 0.9723 - val_specificity_2: 0.9939 - val_dice_coef_necrotic_2: 0.3809 - val_dice_coef_edema_2: 0.9623 - val_dice_coef_enhancing_2: 0.5274
# Epoch 55/400
# 120/120 [==============================] - 114s 955ms/step - loss: 0.0446 - accuracy: 0.9827 - mean_io_u: 0.7724 - dice_coef_2: 0.6393 - precision_2: 0.9861 - sensitivity_2: 0.9798 - specificity_2: 0.9954 - dice_coef_necrotic_2: 0.4838 - dice_coef_edema_2: 0.9796 - dice_coef_enhancing_2: 0.5216 - val_loss: 0.0709 - val_accuracy: 0.9762 - val_mean_io_u: 0.6905 - val_dice_coef_2: 0.5865 - val_precision_2: 0.9814 - val_sensitivity_2: 0.9723 - val_specificity_2: 0.9939 - val_dice_coef_necrotic_2: 0.3674 - val_dice_coef_edema_2: 0.9733 - val_dice_coef_enhancing_2: 0.5207
# Epoch 56/400
# 120/120 [==============================] - 114s 955ms/step - loss: 0.0443 - accuracy: 0.9828 - mean_io_u: 0.7879 - dice_coef_2: 0.6425 - precision_2: 0.9862 - sensitivity_2: 0.9799 - specificity_2: 0.9954 - dice_coef_necrotic_2: 0.4792 - dice_coef_edema_2: 0.9895 - dice_coef_enhancing_2: 0.5255 - val_loss: 0.0694 - val_accuracy: 0.9772 - val_mean_io_u: 0.7510 - val_dice_coef_2: 0.5923 - val_precision_2: 0.9823 - val_sensitivity_2: 0.9733 - val_specificity_2: 0.9942 - val_dice_coef_necrotic_2: 0.3796 - val_dice_coef_edema_2: 0.9659 - val_dice_coef_enhancing_2: 0.5035
# Epoch 57/400
# 120/120 [==============================] - 114s 955ms/step - loss: 0.0433 - accuracy: 0.9832 - mean_io_u: 0.7843 - dice_coef_2: 0.6543 - precision_2: 0.9864 - sensitivity_2: 0.9807 - specificity_2: 0.9955 - dice_coef_necrotic_2: 0.5136 - dice_coef_edema_2: 1.0065 - dice_coef_enhancing_2: 0.5302 - val_loss: 0.0702 - val_accuracy: 0.9764 - val_mean_io_u: 0.6978 - val_dice_coef_2: 0.5852 - val_precision_2: 0.9809 - val_sensitivity_2: 0.9729 - val_specificity_2: 0.9937 - val_dice_coef_necrotic_2: 0.3059 - val_dice_coef_edema_2: 1.0447 - val_dice_coef_enhancing_2: 0.4813
# Epoch 58/400
# 120/120 [==============================] - 114s 955ms/step - loss: 0.0415 - accuracy: 0.9841 - mean_io_u: 0.7752 - dice_coef_2: 0.6600 - precision_2: 0.9871 - sensitivity_2: 0.9816 - specificity_2: 0.9957 - dice_coef_necrotic_2: 0.5307 - dice_coef_edema_2: 1.0134 - dice_coef_enhancing_2: 0.5323 - val_loss: 0.0780 - val_accuracy: 0.9738 - val_mean_io_u: 0.6506 - val_dice_coef_2: 0.5818 - val_precision_2: 0.9795 - val_sensitivity_2: 0.9700 - val_specificity_2: 0.9932 - val_dice_coef_necrotic_2: 0.4489 - val_dice_coef_edema_2: 0.8509 - val_dice_coef_enhancing_2: 0.5688
# Epoch 59/400
# 120/120 [==============================] - 114s 955ms/step - loss: 0.0413 - accuracy: 0.9841 - mean_io_u: 0.7777 - dice_coef_2: 0.6635 - precision_2: 0.9870 - sensitivity_2: 0.9818 - specificity_2: 0.9957 - dice_coef_necrotic_2: 0.5322 - dice_coef_edema_2: 1.0276 - dice_coef_enhancing_2: 0.5354 - val_loss: 0.0718 - val_accuracy: 0.9751 - val_mean_io_u: 0.7111 - val_dice_coef_2: 0.5814 - val_precision_2: 0.9809 - val_sensitivity_2: 0.9710 - val_specificity_2: 0.9937 - val_dice_coef_necrotic_2: 0.3667 - val_dice_coef_edema_2: 0.9628 - val_dice_coef_enhancing_2: 0.5547
# Epoch 60/400
# 120/120 [==============================] - 115s 955ms/step - loss: 0.0409 - accuracy: 0.9843 - mean_io_u: 0.7840 - dice_coef_2: 0.6652 - precision_2: 0.9873 - sensitivity_2: 0.9819 - specificity_2: 0.9958 - dice_coef_necrotic_2: 0.5340 - dice_coef_edema_2: 1.0310 - dice_coef_enhancing_2: 0.5374 - val_loss: 0.0805 - val_accuracy: 0.9735 - val_mean_io_u: 0.7051 - val_dice_coef_2: 0.5792 - val_precision_2: 0.9792 - val_sensitivity_2: 0.9696 - val_specificity_2: 0.9931 - val_dice_coef_necrotic_2: 0.3858 - val_dice_coef_edema_2: 0.9174 - val_dice_coef_enhancing_2: 0.5800
# Epoch 61/400
# 120/120 [==============================] - 115s 955ms/step - loss: 0.0398 - accuracy: 0.9848 - mean_io_u: 0.7928 - dice_coef_2: 0.6752 - precision_2: 0.9875 - sensitivity_2: 0.9826 - specificity_2: 0.9959 - dice_coef_necrotic_2: 0.5556 - dice_coef_edema_2: 1.0512 - dice_coef_enhancing_2: 0.5416 - val_loss: 0.0794 - val_accuracy: 0.9729 - val_mean_io_u: 0.7208 - val_dice_coef_2: 0.5735 - val_precision_2: 0.9789 - val_sensitivity_2: 0.9688 - val_specificity_2: 0.9930 - val_dice_coef_necrotic_2: 0.3923 - val_dice_coef_edema_2: 0.8886 - val_dice_coef_enhancing_2: 0.5926
# Epoch 62/400
# 120/120 [==============================] - 114s 955ms/step - loss: 0.0398 - accuracy: 0.9848 - mean_io_u: 0.7929 - dice_coef_2: 0.6729 - precision_2: 0.9876 - sensitivity_2: 0.9826 - specificity_2: 0.9959 - dice_coef_necrotic_2: 0.5476 - dice_coef_edema_2: 1.0425 - dice_coef_enhancing_2: 0.5475 - val_loss: 0.0773 - val_accuracy: 0.9734 - val_mean_io_u: 0.6851 - val_dice_coef_2: 0.5797 - val_precision_2: 0.9792 - val_sensitivity_2: 0.9692 - val_specificity_2: 0.9932 - val_dice_coef_necrotic_2: 0.3588 - val_dice_coef_edema_2: 0.9677 - val_dice_coef_enhancing_2: 0.6137
# Epoch 63/400
# 120/120 [==============================] - 114s 955ms/step - loss: 0.0396 - accuracy: 0.9849 - mean_io_u: 0.7909 - dice_coef_2: 0.6780 - precision_2: 0.9876 - sensitivity_2: 0.9827 - specificity_2: 0.9959 - dice_coef_necrotic_2: 0.5624 - dice_coef_edema_2: 1.0502 - dice_coef_enhancing_2: 0.5507 - val_loss: 0.0807 - val_accuracy: 0.9738 - val_mean_io_u: 0.7215 - val_dice_coef_2: 0.5923 - val_precision_2: 0.9790 - val_sensitivity_2: 0.9702 - val_specificity_2: 0.9931 - val_dice_coef_necrotic_2: 0.3890 - val_dice_coef_edema_2: 0.9622 - val_dice_coef_enhancing_2: 0.6156
# Epoch 64/400
# 120/120 [==============================] - 115s 955ms/step - loss: 0.0422 - accuracy: 0.9841 - mean_io_u: 0.7958 - dice_coef_2: 0.6653 - precision_2: 0.9872 - sensitivity_2: 0.9817 - specificity_2: 0.9958 - dice_coef_necrotic_2: 0.5497 - dice_coef_edema_2: 1.0261 - dice_coef_enhancing_2: 0.5353 - val_loss: 0.0750 - val_accuracy: 0.9765 - val_mean_io_u: 0.7330 - val_dice_coef_2: 0.5939 - val_precision_2: 0.9821 - val_sensitivity_2: 0.9723 - val_specificity_2: 0.9941 - val_dice_coef_necrotic_2: 0.4069 - val_dice_coef_edema_2: 0.8913 - val_dice_coef_enhancing_2: 0.5775
# Epoch 65/400
# 120/120 [==============================] - 115s 955ms/step - loss: 0.0463 - accuracy: 0.9828 - mean_io_u: 0.7707 - dice_coef_2: 0.6424 - precision_2: 0.9866 - sensitivity_2: 0.9797 - specificity_2: 0.9956 - dice_coef_necrotic_2: 0.5242 - dice_coef_edema_2: 0.9644 - dice_coef_enhancing_2: 0.5164 - val_loss: 0.0719 - val_accuracy: 0.9754 - val_mean_io_u: 0.7024 - val_dice_coef_2: 0.5743 - val_precision_2: 0.9808 - val_sensitivity_2: 0.9711 - val_specificity_2: 0.9937 - val_dice_coef_necrotic_2: 0.3005 - val_dice_coef_edema_2: 1.0629 - val_dice_coef_enhancing_2: 0.4958
# Epoch 66/400
# 120/120 [==============================] - 114s 955ms/step - loss: 0.0441 - accuracy: 0.9834 - mean_io_u: 0.7983 - dice_coef_2: 0.6507 - precision_2: 0.9868 - sensitivity_2: 0.9806 - specificity_2: 0.9956 - dice_coef_necrotic_2: 0.5171 - dice_coef_edema_2: 1.0073 - dice_coef_enhancing_2: 0.5198 - val_loss: 0.0739 - val_accuracy: 0.9749 - val_mean_io_u: 0.7236 - val_dice_coef_2: 0.5854 - val_precision_2: 0.9808 - val_sensitivity_2: 0.9704 - val_specificity_2: 0.9937 - val_dice_coef_necrotic_2: 0.3677 - val_dice_coef_edema_2: 1.0080 - val_dice_coef_enhancing_2: 0.5440
# Epoch 67/400
# 120/120 [==============================] - 114s 955ms/step - loss: 0.0424 - accuracy: 0.9842 - mean_io_u: 0.8111 - dice_coef_2: 0.6671 - precision_2: 0.9873 - sensitivity_2: 0.9816 - specificity_2: 0.9958 - dice_coef_necrotic_2: 0.5447 - dice_coef_edema_2: 1.0399 - dice_coef_enhancing_2: 0.5344 - val_loss: 0.0721 - val_accuracy: 0.9762 - val_mean_io_u: 0.7416 - val_dice_coef_2: 0.5858 - val_precision_2: 0.9821 - val_sensitivity_2: 0.9715 - val_specificity_2: 0.9941 - val_dice_coef_necrotic_2: 0.3942 - val_dice_coef_edema_2: 0.9102 - val_dice_coef_enhancing_2: 0.5609
# Epoch 68/400
# 120/120 [==============================] - 114s 955ms/step - loss: 0.0404 - accuracy: 0.9846 - mean_io_u: 0.8177 - dice_coef_2: 0.6744 - precision_2: 0.9875 - sensitivity_2: 0.9822 - specificity_2: 0.9959 - dice_coef_necrotic_2: 0.5559 - dice_coef_edema_2: 1.0438 - dice_coef_enhancing_2: 0.5426 - val_loss: 0.0768 - val_accuracy: 0.9740 - val_mean_io_u: 0.6675 - val_dice_coef_2: 0.5674 - val_precision_2: 0.9806 - val_sensitivity_2: 0.9689 - val_specificity_2: 0.9936 - val_dice_coef_necrotic_2: 0.4066 - val_dice_coef_edema_2: 0.8630 - val_dice_coef_enhancing_2: 0.5554
# Epoch 69/400
# 120/120 [==============================] - 114s 954ms/step - loss: 0.0392 - accuracy: 0.9852 - mean_io_u: 0.8189 - dice_coef_2: 0.6776 - precision_2: 0.9879 - sensitivity_2: 0.9830 - specificity_2: 0.9960 - dice_coef_necrotic_2: 0.5569 - dice_coef_edema_2: 1.0591 - dice_coef_enhancing_2: 0.5485 - val_loss: 0.0870 - val_accuracy: 0.9697 - val_mean_io_u: 0.6137 - val_dice_coef_2: 0.5467 - val_precision_2: 0.9779 - val_sensitivity_2: 0.9640 - val_specificity_2: 0.9928 - val_dice_coef_necrotic_2: 0.4098 - val_dice_coef_edema_2: 0.7808 - val_dice_coef_enhancing_2: 0.6383
# Epoch 70/400
# 120/120 [==============================] - 114s 955ms/step - loss: 0.0378 - accuracy: 0.9855 - mean_io_u: 0.8054 - dice_coef_2: 0.6856 - precision_2: 0.9881 - sensitivity_2: 0.9835 - specificity_2: 0.9960 - dice_coef_necrotic_2: 0.5640 - dice_coef_edema_2: 1.0642 - dice_coef_enhancing_2: 0.5651 - val_loss: 0.0760 - val_accuracy: 0.9747 - val_mean_io_u: 0.7325 - val_dice_coef_2: 0.5924 - val_precision_2: 0.9795 - val_sensitivity_2: 0.9714 - val_specificity_2: 0.9932 - val_dice_coef_necrotic_2: 0.4010 - val_dice_coef_edema_2: 0.9074 - val_dice_coef_enhancing_2: 0.6072
# Epoch 71/400
# 120/120 [==============================] - 114s 955ms/step - loss: 0.0370 - accuracy: 0.9858 - mean_io_u: 0.8155 - dice_coef_2: 0.6940 - precision_2: 0.9883 - sensitivity_2: 0.9839 - specificity_2: 0.9961 - dice_coef_necrotic_2: 0.5825 - dice_coef_edema_2: 1.0791 - dice_coef_enhancing_2: 0.5668 - val_loss: 0.0802 - val_accuracy: 0.9730 - val_mean_io_u: 0.6813 - val_dice_coef_2: 0.5874 - val_precision_2: 0.9779 - val_sensitivity_2: 0.9697 - val_specificity_2: 0.9927 - val_dice_coef_necrotic_2: 0.3549 - val_dice_coef_edema_2: 0.9782 - val_dice_coef_enhancing_2: 0.6324
# Epoch 72/400
# 120/120 [==============================] - 114s 955ms/step - loss: 0.0355 - accuracy: 0.9864 - mean_io_u: 0.8177 - dice_coef_2: 0.7006 - precision_2: 0.9888 - sensitivity_2: 0.9845 - specificity_2: 0.9963 - dice_coef_necrotic_2: 0.6006 - dice_coef_edema_2: 1.0836 - dice_coef_enhancing_2: 0.5764 - val_loss: 0.0791 - val_accuracy: 0.9738 - val_mean_io_u: 0.6597 - val_dice_coef_2: 0.5968 - val_precision_2: 0.9776 - val_sensitivity_2: 0.9711 - val_specificity_2: 0.9926 - val_dice_coef_necrotic_2: 0.2840 - val_dice_coef_edema_2: 1.1146 - val_dice_coef_enhancing_2: 0.6264
# Epoch 73/400
# 120/120 [==============================] - 114s 955ms/step - loss: 0.0341 - accuracy: 0.9869 - mean_io_u: 0.8343 - dice_coef_2: 0.7109 - precision_2: 0.9891 - sensitivity_2: 0.9852 - specificity_2: 0.9964 - dice_coef_necrotic_2: 0.6159 - dice_coef_edema_2: 1.1008 - dice_coef_enhancing_2: 0.5818 - val_loss: 0.0778 - val_accuracy: 0.9741 - val_mean_io_u: 0.6695 - val_dice_coef_2: 0.6038 - val_precision_2: 0.9775 - val_sensitivity_2: 0.9718 - val_specificity_2: 0.9925 - val_dice_coef_necrotic_2: 0.2816 - val_dice_coef_edema_2: 1.1339 - val_dice_coef_enhancing_2: 0.6300
# Epoch 74/400
# 120/120 [==============================] - 114s 955ms/step - loss: 0.0329 - accuracy: 0.9873 - mean_io_u: 0.8380 - dice_coef_2: 0.7198 - precision_2: 0.9894 - sensitivity_2: 0.9857 - specificity_2: 0.9965 - dice_coef_necrotic_2: 0.6308 - dice_coef_edema_2: 1.1197 - dice_coef_enhancing_2: 0.5910 - val_loss: 0.0749 - val_accuracy: 0.9757 - val_mean_io_u: 0.7382 - val_dice_coef_2: 0.6118 - val_precision_2: 0.9786 - val_sensitivity_2: 0.9737 - val_specificity_2: 0.9929 - val_dice_coef_necrotic_2: 0.2726 - val_dice_coef_edema_2: 1.1168 - val_dice_coef_enhancing_2: 0.6227
# Epoch 75/400
# 120/120 [==============================] - 114s 955ms/step - loss: 0.0323 - accuracy: 0.9876 - mean_io_u: 0.8412 - dice_coef_2: 0.7242 - precision_2: 0.9895 - sensitivity_2: 0.9860 - specificity_2: 0.9965 - dice_coef_necrotic_2: 0.6331 - dice_coef_edema_2: 1.1284 - dice_coef_enhancing_2: 0.5988 - val_loss: 0.0771 - val_accuracy: 0.9754 - val_mean_io_u: 0.7056 - val_dice_coef_2: 0.6155 - val_precision_2: 0.9781 - val_sensitivity_2: 0.9736 - val_specificity_2: 0.9927 - val_dice_coef_necrotic_2: 0.2910 - val_dice_coef_edema_2: 1.1428 - val_dice_coef_enhancing_2: 0.6096
# Epoch 76/400
# 120/120 [==============================] - 114s 955ms/step - loss: 0.0318 - accuracy: 0.9878 - mean_io_u: 0.8341 - dice_coef_2: 0.7285 - precision_2: 0.9897 - sensitivity_2: 0.9862 - specificity_2: 0.9966 - dice_coef_necrotic_2: 0.6362 - dice_coef_edema_2: 1.1367 - dice_coef_enhancing_2: 0.6031 - val_loss: 0.0741 - val_accuracy: 0.9768 - val_mean_io_u: 0.7264 - val_dice_coef_2: 0.6287 - val_precision_2: 0.9794 - val_sensitivity_2: 0.9750 - val_specificity_2: 0.9932 - val_dice_coef_necrotic_2: 0.3249 - val_dice_coef_edema_2: 1.1150 - val_dice_coef_enhancing_2: 0.6140
# Epoch 77/400
# 120/120 [==============================] - 114s 955ms/step - loss: 0.0311 - accuracy: 0.9880 - mean_io_u: 0.8406 - dice_coef_2: 0.7339 - precision_2: 0.9899 - sensitivity_2: 0.9866 - specificity_2: 0.9966 - dice_coef_necrotic_2: 0.6398 - dice_coef_edema_2: 1.1478 - dice_coef_enhancing_2: 0.6101 - val_loss: 0.0730 - val_accuracy: 0.9770 - val_mean_io_u: 0.7712 - val_dice_coef_2: 0.6327 - val_precision_2: 0.9798 - val_sensitivity_2: 0.9750 - val_specificity_2: 0.9933 - val_dice_coef_necrotic_2: 0.3892 - val_dice_coef_edema_2: 1.0288 - val_dice_coef_enhancing_2: 0.6234
# Epoch 78/400
# 120/120 [==============================] - 114s 955ms/step - loss: 0.0315 - accuracy: 0.9879 - mean_io_u: 0.8364 - dice_coef_2: 0.7322 - precision_2: 0.9897 - sensitivity_2: 0.9864 - specificity_2: 0.9966 - dice_coef_necrotic_2: 0.6334 - dice_coef_edema_2: 1.1401 - dice_coef_enhancing_2: 0.6171 - val_loss: 0.0700 - val_accuracy: 0.9773 - val_mean_io_u: 0.7580 - val_dice_coef_2: 0.6275 - val_precision_2: 0.9804 - val_sensitivity_2: 0.9750 - val_specificity_2: 0.9935 - val_dice_coef_necrotic_2: 0.3771 - val_dice_coef_edema_2: 1.0234 - val_dice_coef_enhancing_2: 0.6323
# Epoch 79/400
# 120/120 [==============================] - 114s 955ms/step - loss: 0.0310 - accuracy: 0.9881 - mean_io_u: 0.8393 - dice_coef_2: 0.7352 - precision_2: 0.9899 - sensitivity_2: 0.9866 - specificity_2: 0.9966 - dice_coef_necrotic_2: 0.6381 - dice_coef_edema_2: 1.1432 - dice_coef_enhancing_2: 0.6213 - val_loss: 0.0819 - val_accuracy: 0.9724 - val_mean_io_u: 0.7386 - val_dice_coef_2: 0.6008 - val_precision_2: 0.9771 - val_sensitivity_2: 0.9694 - val_specificity_2: 0.9924 - val_dice_coef_necrotic_2: 0.4481 - val_dice_coef_edema_2: 0.9129 - val_dice_coef_enhancing_2: 0.6897
# Epoch 80/400
# 120/120 [==============================] - 114s 955ms/step - loss: 0.0315 - accuracy: 0.9879 - mean_io_u: 0.8361 - dice_coef_2: 0.7347 - precision_2: 0.9897 - sensitivity_2: 0.9865 - specificity_2: 0.9966 - dice_coef_necrotic_2: 0.6363 - dice_coef_edema_2: 1.1379 - dice_coef_enhancing_2: 0.6279 - val_loss: 0.0823 - val_accuracy: 0.9721 - val_mean_io_u: 0.6970 - val_dice_coef_2: 0.6039 - val_precision_2: 0.9767 - val_sensitivity_2: 0.9691 - val_specificity_2: 0.9923 - val_dice_coef_necrotic_2: 0.4366 - val_dice_coef_edema_2: 0.9339 - val_dice_coef_enhancing_2: 0.6920
# Epoch 81/400
# 120/120 [==============================] - 114s 954ms/step - loss: 0.0335 - accuracy: 0.9873 - mean_io_u: 0.8272 - dice_coef_2: 0.7261 - precision_2: 0.9892 - sensitivity_2: 0.9857 - specificity_2: 0.9964 - dice_coef_necrotic_2: 0.6335 - dice_coef_edema_2: 1.1230 - dice_coef_enhancing_2: 0.6145 - val_loss: 0.0763 - val_accuracy: 0.9770 - val_mean_io_u: 0.7533 - val_dice_coef_2: 0.6252 - val_precision_2: 0.9795 - val_sensitivity_2: 0.9754 - val_specificity_2: 0.9932 - val_dice_coef_necrotic_2: 0.3159 - val_dice_coef_edema_2: 1.0556 - val_dice_coef_enhancing_2: 0.6298
# Epoch 82/400
# ...
# Epoch 374/400
# 120/120 [==============================] - 114s 952ms/step - loss: 0.0151 - accuracy: 0.9939 - mean_io_u: 0.9091 - dice_coef_2: 0.8658 - precision_2: 0.9943 - sensitivity_2: 0.9935 - specificity_2: 0.9981 - dice_coef_necrotic_2: 0.7985 - dice_coef_edema_2: 1.3059 - dice_coef_enhancing_2: 0.7947 - val_loss: 0.0992 - val_accuracy: 0.9822 - val_mean_io_u: 0.9143 - val_dice_coef_2: 0.7434 - val_precision_2: 0.9828 - val_sensitivity_2: 0.9818 - val_specificity_2: 0.9943 - val_dice_coef_necrotic_2: 0.5031 - val_dice_coef_edema_2: 1.0799 - val_dice_coef_enhancing_2: 0.6921
# Epoch 375/400
# 120/120 [==============================] - 114s 952ms/step - loss: 0.0146 - accuracy: 0.9941 - mean_io_u: 0.9141 - dice_coef_2: 0.8697 - precision_2: 0.9945 - sensitivity_2: 0.9937 - specificity_2: 0.9982 - dice_coef_necrotic_2: 0.8061 - dice_coef_edema_2: 1.3120 - dice_coef_enhancing_2: 0.7969 - val_loss: 0.0904 - val_accuracy: 0.9827 - val_mean_io_u: 0.9083 - val_dice_coef_2: 0.7500 - val_precision_2: 0.9833 - val_sensitivity_2: 0.9823 - val_specificity_2: 0.9944 - val_dice_coef_necrotic_2: 0.5312 - val_dice_coef_edema_2: 1.0942 - val_dice_coef_enhancing_2: 0.7103
# Epoch 376/400
# 120/120 [==============================] - 114s 952ms/step - loss: 0.0142 - accuracy: 0.9942 - mean_io_u: 0.9205 - dice_coef_2: 0.8732 - precision_2: 0.9946 - sensitivity_2: 0.9939 - specificity_2: 0.9982 - dice_coef_necrotic_2: 0.8131 - dice_coef_edema_2: 1.3192 - dice_coef_enhancing_2: 0.7972 - val_loss: 0.0973 - val_accuracy: 0.9819 - val_mean_io_u: 0.9170 - val_dice_coef_2: 0.7454 - val_precision_2: 0.9826 - val_sensitivity_2: 0.9815 - val_specificity_2: 0.9942 - val_dice_coef_necrotic_2: 0.5447 - val_dice_coef_edema_2: 1.0523 - val_dice_coef_enhancing_2: 0.6841
# Epoch 377/400
# 120/120 [==============================] - 114s 952ms/step - loss: 0.0140 - accuracy: 0.9943 - mean_io_u: 0.9183 - dice_coef_2: 0.8766 - precision_2: 0.9947 - sensitivity_2: 0.9940 - specificity_2: 0.9982 - dice_coef_necrotic_2: 0.8150 - dice_coef_edema_2: 1.3187 - dice_coef_enhancing_2: 0.7987 - val_loss: 0.1107 - val_accuracy: 0.9816 - val_mean_io_u: 0.9281 - val_dice_coef_2: 0.7423 - val_precision_2: 0.9823 - val_sensitivity_2: 0.9812 - val_specificity_2: 0.9941 - val_dice_coef_necrotic_2: 0.5460 - val_dice_coef_edema_2: 1.0312 - val_dice_coef_enhancing_2: 0.6745
# Epoch 378/400
# 120/120 [==============================] - 114s 952ms/step - loss: 0.0138 - accuracy: 0.9944 - mean_io_u: 0.9175 - dice_coef_2: 0.8793 - precision_2: 0.9947 - sensitivity_2: 0.9941 - specificity_2: 0.9982 - dice_coef_necrotic_2: 0.8171 - dice_coef_edema_2: 1.3209 - dice_coef_enhancing_2: 0.8014 - val_loss: 0.1101 - val_accuracy: 0.9818 - val_mean_io_u: 0.9285 - val_dice_coef_2: 0.7428 - val_precision_2: 0.9824 - val_sensitivity_2: 0.9814 - val_specificity_2: 0.9941 - val_dice_coef_necrotic_2: 0.5599 - val_dice_coef_edema_2: 1.0346 - val_dice_coef_enhancing_2: 0.6679
# Epoch 379/400
# 120/120 [==============================] - 114s 952ms/step - loss: 0.0139 - accuracy: 0.9944 - mean_io_u: 0.9153 - dice_coef_2: 0.8802 - precision_2: 0.9947 - sensitivity_2: 0.9941 - specificity_2: 0.9982 - dice_coef_necrotic_2: 0.8166 - dice_coef_edema_2: 1.3203 - dice_coef_enhancing_2: 0.8059 - val_loss: 0.1267 - val_accuracy: 0.9816 - val_mean_io_u: 0.9330 - val_dice_coef_2: 0.7448 - val_precision_2: 0.9821 - val_sensitivity_2: 0.9813 - val_specificity_2: 0.9940 - val_dice_coef_necrotic_2: 0.5559 - val_dice_coef_edema_2: 1.0142 - val_dice_coef_enhancing_2: 0.6417
# Epoch 380/400
# 120/120 [==============================] - 114s 952ms/step - loss: 0.0138 - accuracy: 0.9944 - mean_io_u: 0.9129 - dice_coef_2: 0.8815 - precision_2: 0.9947 - sensitivity_2: 0.9941 - specificity_2: 0.9982 - dice_coef_necrotic_2: 0.8188 - dice_coef_edema_2: 1.3219 - dice_coef_enhancing_2: 0.8080 - val_loss: 0.1258 - val_accuracy: 0.9815 - val_mean_io_u: 0.9295 - val_dice_coef_2: 0.7405 - val_precision_2: 0.9820 - val_sensitivity_2: 0.9812 - val_specificity_2: 0.9940 - val_dice_coef_necrotic_2: 0.5615 - val_dice_coef_edema_2: 0.9930 - val_dice_coef_enhancing_2: 0.6516
# Epoch 381/400
# 120/120 [==============================] - 114s 952ms/step - loss: 0.0138 - accuracy: 0.9944 - mean_io_u: 0.9149 - dice_coef_2: 0.8820 - precision_2: 0.9947 - sensitivity_2: 0.9941 - specificity_2: 0.9982 - dice_coef_necrotic_2: 0.8195 - dice_coef_edema_2: 1.3221 - dice_coef_enhancing_2: 0.8093 - val_loss: 0.1430 - val_accuracy: 0.9808 - val_mean_io_u: 0.9273 - val_dice_coef_2: 0.7363 - val_precision_2: 0.9812 - val_sensitivity_2: 0.9804 - val_specificity_2: 0.9938 - val_dice_coef_necrotic_2: 0.5443 - val_dice_coef_edema_2: 0.9549 - val_dice_coef_enhancing_2: 0.6387
# Epoch 382/400
# 120/120 [==============================] - 114s 952ms/step - loss: 0.0138 - accuracy: 0.9944 - mean_io_u: 0.9121 - dice_coef_2: 0.8822 - precision_2: 0.9947 - sensitivity_2: 0.9941 - specificity_2: 0.9982 - dice_coef_necrotic_2: 0.8204 - dice_coef_edema_2: 1.3224 - dice_coef_enhancing_2: 0.8094 - val_loss: 0.1427 - val_accuracy: 0.9801 - val_mean_io_u: 0.9200 - val_dice_coef_2: 0.7315 - val_precision_2: 0.9806 - val_sensitivity_2: 0.9798 - val_specificity_2: 0.9935 - val_dice_coef_necrotic_2: 0.5076 - val_dice_coef_edema_2: 0.9474 - val_dice_coef_enhancing_2: 0.6149
# Epoch 383/400
# 120/120 [==============================] - 114s 952ms/step - loss: 0.0138 - accuracy: 0.9944 - mean_io_u: 0.9117 - dice_coef_2: 0.8823 - precision_2: 0.9947 - sensitivity_2: 0.9941 - specificity_2: 0.9982 - dice_coef_necrotic_2: 0.8199 - dice_coef_edema_2: 1.3216 - dice_coef_enhancing_2: 0.8105 - val_loss: 0.1453 - val_accuracy: 0.9793 - val_mean_io_u: 0.9186 - val_dice_coef_2: 0.7233 - val_precision_2: 0.9798 - val_sensitivity_2: 0.9790 - val_specificity_2: 0.9933 - val_dice_coef_necrotic_2: 0.4730 - val_dice_coef_edema_2: 0.9494 - val_dice_coef_enhancing_2: 0.5715
# Epoch 384/400
# 120/120 [==============================] - 114s 952ms/step - loss: 0.0137 - accuracy: 0.9944 - mean_io_u: 0.9164 - dice_coef_2: 0.8830 - precision_2: 0.9948 - sensitivity_2: 0.9941 - specificity_2: 0.9983 - dice_coef_necrotic_2: 0.8211 - dice_coef_edema_2: 1.3219 - dice_coef_enhancing_2: 0.8098 - val_loss: 0.1223 - val_accuracy: 0.9806 - val_mean_io_u: 0.9103 - val_dice_coef_2: 0.7294 - val_precision_2: 0.9811 - val_sensitivity_2: 0.9803 - val_specificity_2: 0.9937 - val_dice_coef_necrotic_2: 0.4574 - val_dice_coef_edema_2: 1.0012 - val_dice_coef_enhancing_2: 0.6132
# Epoch 385/400
# 120/120 [==============================] - 114s 952ms/step - loss: 0.0135 - accuracy: 0.9945 - mean_io_u: 0.9205 - dice_coef_2: 0.8842 - precision_2: 0.9948 - sensitivity_2: 0.9942 - specificity_2: 0.9983 - dice_coef_necrotic_2: 0.8188 - dice_coef_edema_2: 1.3276 - dice_coef_enhancing_2: 0.8122 - val_loss: 0.1115 - val_accuracy: 0.9806 - val_mean_io_u: 0.9139 - val_dice_coef_2: 0.7293 - val_precision_2: 0.9812 - val_sensitivity_2: 0.9802 - val_specificity_2: 0.9937 - val_dice_coef_necrotic_2: 0.4976 - val_dice_coef_edema_2: 0.9672 - val_dice_coef_enhancing_2: 0.6080
# Epoch 386/400
# 120/120 [==============================] - 114s 952ms/step - loss: 0.0133 - accuracy: 0.9946 - mean_io_u: 0.9239 - dice_coef_2: 0.8847 - precision_2: 0.9949 - sensitivity_2: 0.9943 - specificity_2: 0.9983 - dice_coef_necrotic_2: 0.8202 - dice_coef_edema_2: 1.3280 - dice_coef_enhancing_2: 0.8125 - val_loss: 0.0945 - val_accuracy: 0.9821 - val_mean_io_u: 0.9021 - val_dice_coef_2: 0.7436 - val_precision_2: 0.9828 - val_sensitivity_2: 0.9818 - val_specificity_2: 0.9943 - val_dice_coef_necrotic_2: 0.5386 - val_dice_coef_edema_2: 1.0430 - val_dice_coef_enhancing_2: 0.6406
# Epoch 387/400
# 120/120 [==============================] - 114s 952ms/step - loss: 0.0133 - accuracy: 0.9946 - mean_io_u: 0.9225 - dice_coef_2: 0.8842 - precision_2: 0.9949 - sensitivity_2: 0.9943 - specificity_2: 0.9983 - dice_coef_necrotic_2: 0.8183 - dice_coef_edema_2: 1.3296 - dice_coef_enhancing_2: 0.8109 - val_loss: 0.0843 - val_accuracy: 0.9827 - val_mean_io_u: 0.8886 - val_dice_coef_2: 0.7486 - val_precision_2: 0.9834 - val_sensitivity_2: 0.9823 - val_specificity_2: 0.9945 - val_dice_coef_necrotic_2: 0.5508 - val_dice_coef_edema_2: 1.0927 - val_dice_coef_enhancing_2: 0.6854
# Epoch 388/400
# 120/120 [==============================] - 114s 952ms/step - loss: 0.0133 - accuracy: 0.9946 - mean_io_u: 0.9245 - dice_coef_2: 0.8824 - precision_2: 0.9949 - sensitivity_2: 0.9943 - specificity_2: 0.9983 - dice_coef_necrotic_2: 0.8174 - dice_coef_edema_2: 1.3290 - dice_coef_enhancing_2: 0.8093 - val_loss: 0.0869 - val_accuracy: 0.9825 - val_mean_io_u: 0.8818 - val_dice_coef_2: 0.7529 - val_precision_2: 0.9830 - val_sensitivity_2: 0.9821 - val_specificity_2: 0.9943 - val_dice_coef_necrotic_2: 0.5455 - val_dice_coef_edema_2: 1.1628 - val_dice_coef_enhancing_2: 0.6737
# Epoch 389/400
# 120/120 [==============================] - 114s 952ms/step - loss: 0.0133 - accuracy: 0.9946 - mean_io_u: 0.9256 - dice_coef_2: 0.8825 - precision_2: 0.9949 - sensitivity_2: 0.9943 - specificity_2: 0.9983 - dice_coef_necrotic_2: 0.8164 - dice_coef_edema_2: 1.3304 - dice_coef_enhancing_2: 0.8086 - val_loss: 0.0888 - val_accuracy: 0.9823 - val_mean_io_u: 0.8830 - val_dice_coef_2: 0.7543 - val_precision_2: 0.9828 - val_sensitivity_2: 0.9820 - val_specificity_2: 0.9943 - val_dice_coef_necrotic_2: 0.5329 - val_dice_coef_edema_2: 1.1679 - val_dice_coef_enhancing_2: 0.6904
# Epoch 390/400
# 120/120 [==============================] - 114s 952ms/step - loss: 0.0132 - accuracy: 0.9946 - mean_io_u: 0.9259 - dice_coef_2: 0.8836 - precision_2: 0.9949 - sensitivity_2: 0.9943 - specificity_2: 0.9983 - dice_coef_necrotic_2: 0.8183 - dice_coef_edema_2: 1.3310 - dice_coef_enhancing_2: 0.8078 - val_loss: 0.0901 - val_accuracy: 0.9819 - val_mean_io_u: 0.8708 - val_dice_coef_2: 0.7537 - val_precision_2: 0.9824 - val_sensitivity_2: 0.9817 - val_specificity_2: 0.9941 - val_dice_coef_necrotic_2: 0.5012 - val_dice_coef_edema_2: 1.2160 - val_dice_coef_enhancing_2: 0.6691
# Epoch 391/400
# 120/120 [==============================] - 114s 953ms/step - loss: 0.0132 - accuracy: 0.9946 - mean_io_u: 0.9262 - dice_coef_2: 0.8846 - precision_2: 0.9950 - sensitivity_2: 0.9944 - specificity_2: 0.9983 - dice_coef_necrotic_2: 0.8173 - dice_coef_edema_2: 1.3301 - dice_coef_enhancing_2: 0.8094 - val_loss: 0.0863 - val_accuracy: 0.9823 - val_mean_io_u: 0.8851 - val_dice_coef_2: 0.7560 - val_precision_2: 0.9828 - val_sensitivity_2: 0.9820 - val_specificity_2: 0.9943 - val_dice_coef_necrotic_2: 0.5163 - val_dice_coef_edema_2: 1.2001 - val_dice_coef_enhancing_2: 0.6778
# Epoch 392/400
# 120/120 [==============================] - 114s 953ms/step - loss: 0.0133 - accuracy: 0.9946 - mean_io_u: 0.9249 - dice_coef_2: 0.8834 - precision_2: 0.9949 - sensitivity_2: 0.9943 - specificity_2: 0.9983 - dice_coef_necrotic_2: 0.8157 - dice_coef_edema_2: 1.3287 - dice_coef_enhancing_2: 0.8111 - val_loss: 0.0936 - val_accuracy: 0.9822 - val_mean_io_u: 0.8996 - val_dice_coef_2: 0.7502 - val_precision_2: 0.9827 - val_sensitivity_2: 0.9819 - val_specificity_2: 0.9942 - val_dice_coef_necrotic_2: 0.5070 - val_dice_coef_edema_2: 1.1620 - val_dice_coef_enhancing_2: 0.6506
# Epoch 393/400
# 120/120 [==============================] - 114s 953ms/step - loss: 0.0135 - accuracy: 0.9945 - mean_io_u: 0.9232 - dice_coef_2: 0.8805 - precision_2: 0.9949 - sensitivity_2: 0.9942 - specificity_2: 0.9983 - dice_coef_necrotic_2: 0.8122 - dice_coef_edema_2: 1.3275 - dice_coef_enhancing_2: 0.8107 - val_loss: 0.0898 - val_accuracy: 0.9823 - val_mean_io_u: 0.8893 - val_dice_coef_2: 0.7503 - val_precision_2: 0.9829 - val_sensitivity_2: 0.9820 - val_specificity_2: 0.9943 - val_dice_coef_necrotic_2: 0.5286 - val_dice_coef_edema_2: 1.1825 - val_dice_coef_enhancing_2: 0.6226
# Epoch 394/400
# 120/120 [==============================] - 114s 952ms/step - loss: 0.0138 - accuracy: 0.9944 - mean_io_u: 0.9211 - dice_coef_2: 0.8792 - precision_2: 0.9948 - sensitivity_2: 0.9941 - specificity_2: 0.9983 - dice_coef_necrotic_2: 0.8110 - dice_coef_edema_2: 1.3262 - dice_coef_enhancing_2: 0.8099 - val_loss: 0.0894 - val_accuracy: 0.9825 - val_mean_io_u: 0.8911 - val_dice_coef_2: 0.7533 - val_precision_2: 0.9831 - val_sensitivity_2: 0.9822 - val_specificity_2: 0.9944 - val_dice_coef_necrotic_2: 0.5607 - val_dice_coef_edema_2: 1.1646 - val_dice_coef_enhancing_2: 0.6086
# Epoch 395/400
# 120/120 [==============================] - 114s 952ms/step - loss: 0.0138 - accuracy: 0.9944 - mean_io_u: 0.9164 - dice_coef_2: 0.8810 - precision_2: 0.9948 - sensitivity_2: 0.9941 - specificity_2: 0.9983 - dice_coef_necrotic_2: 0.8122 - dice_coef_edema_2: 1.3261 - dice_coef_enhancing_2: 0.8105 - val_loss: 0.0985 - val_accuracy: 0.9822 - val_mean_io_u: 0.9070 - val_dice_coef_2: 0.7479 - val_precision_2: 0.9827 - val_sensitivity_2: 0.9819 - val_specificity_2: 0.9942 - val_dice_coef_necrotic_2: 0.5842 - val_dice_coef_edema_2: 1.0903 - val_dice_coef_enhancing_2: 0.6203
# Epoch 396/400
# 120/120 [==============================] - 114s 952ms/step - loss: 0.0136 - accuracy: 0.9945 - mean_io_u: 0.9165 - dice_coef_2: 0.8820 - precision_2: 0.9948 - sensitivity_2: 0.9942 - specificity_2: 0.9983 - dice_coef_necrotic_2: 0.8164 - dice_coef_edema_2: 1.3277 - dice_coef_enhancing_2: 0.8119 - val_loss: 0.1123 - val_accuracy: 0.9816 - val_mean_io_u: 0.9121 - val_dice_coef_2: 0.7428 - val_precision_2: 0.9820 - val_sensitivity_2: 0.9813 - val_specificity_2: 0.9940 - val_dice_coef_necrotic_2: 0.5161 - val_dice_coef_edema_2: 1.0852 - val_dice_coef_enhancing_2: 0.5834
# Epoch 397/400
# 120/120 [==============================] - 114s 952ms/step - loss: 0.0133 - accuracy: 0.9946 - mean_io_u: 0.9190 - dice_coef_2: 0.8835 - precision_2: 0.9949 - sensitivity_2: 0.9943 - specificity_2: 0.9983 - dice_coef_necrotic_2: 0.8200 - dice_coef_edema_2: 1.3286 - dice_coef_enhancing_2: 0.8117 - val_loss: 0.1026 - val_accuracy: 0.9819 - val_mean_io_u: 0.8868 - val_dice_coef_2: 0.7484 - val_precision_2: 0.9823 - val_sensitivity_2: 0.9816 - val_specificity_2: 0.9941 - val_dice_coef_necrotic_2: 0.4914 - val_dice_coef_edema_2: 1.1554 - val_dice_coef_enhancing_2: 0.5926
# Epoch 398/400
# 120/120 [==============================] - 114s 952ms/step - loss: 0.0133 - accuracy: 0.9946 - mean_io_u: 0.9173 - dice_coef_2: 0.8832 - precision_2: 0.9949 - sensitivity_2: 0.9943 - specificity_2: 0.9983 - dice_coef_necrotic_2: 0.8204 - dice_coef_edema_2: 1.3298 - dice_coef_enhancing_2: 0.8097 - val_loss: 0.0936 - val_accuracy: 0.9824 - val_mean_io_u: 0.8855 - val_dice_coef_2: 0.7559 - val_precision_2: 0.9829 - val_sensitivity_2: 0.9821 - val_specificity_2: 0.9943 - val_dice_coef_necrotic_2: 0.5329 - val_dice_coef_edema_2: 1.1202 - val_dice_coef_enhancing_2: 0.6499
# Epoch 399/400
# 120/120 [==============================] - 114s 952ms/step - loss: 0.0133 - accuracy: 0.9946 - mean_io_u: 0.9196 - dice_coef_2: 0.8827 - precision_2: 0.9949 - sensitivity_2: 0.9943 - specificity_2: 0.9983 - dice_coef_necrotic_2: 0.8183 - dice_coef_edema_2: 1.3307 - dice_coef_enhancing_2: 0.8078 - val_loss: 0.0948 - val_accuracy: 0.9826 - val_mean_io_u: 0.9010 - val_dice_coef_2: 0.7537 - val_precision_2: 0.9831 - val_sensitivity_2: 0.9822 - val_specificity_2: 0.9944 - val_dice_coef_necrotic_2: 0.5495 - val_dice_coef_edema_2: 1.0662 - val_dice_coef_enhancing_2: 0.6960
# Epoch 400/400
# 120/120 [==============================] - 114s 952ms/step - loss: 0.0134 - accuracy: 0.9945 - mean_io_u: 0.9188 - dice_coef_2: 0.8823 - precision_2: 0.9949 - sensitivity_2: 0.9943 - specificity_2: 0.9983 - dice_coef_necrotic_2: 0.8198 - dice_coef_edema_2: 1.3286 - dice_coef_enhancing_2: 0.8029 - val_loss: 0.0919 - val_accuracy: 0.9827 - val_mean_io_u: 0.9099 - val_dice_coef_2: 0.7491 - val_precision_2: 0.9834 - val_sensitivity_2: 0.9823 - val_specificity_2: 0.9945 - val_dice_coef_necrotic_2: 0.5338 - val_dice_coef_edema_2: 1.0683 - val_dice_coef_enhancing_2: 0.7247
# Runtime: 12 hours, 42 minutes, 53 seconds

# %% [markdown]
# # test data

# %%
img_num = 82

test_img = np.load("BraTS2020_TrainingData/input_data_128/test/images/image_"+str(img_num)+".npy")

test_mask = np.load("BraTS2020_TrainingData/input_data_128/test/masks/mask_"+str(img_num)+".npy")
test_mask_argmax=np.argmax(test_mask, axis=3)

test_img_input = np.expand_dims(test_img, axis=0)
test_prediction = model_2.predict(test_img_input)
test_prediction_argmax=np.argmax(test_prediction, axis=4)[0,:,:,:]


print(test_prediction_argmax.shape)
print(test_mask_argmax.shape)
print(np.unique(test_prediction_argmax))


#Plot individual slices from test predictions for verification
from matplotlib import pyplot as plt
import random

#n_slice=random.randint(0, test_prediction_argmax.shape[2])
n_slice = 55
plt.figure(figsize=(12, 8))
plt.subplot(231)
plt.title('Testing Image')
plt.imshow(test_img[:,:,n_slice,1], cmap='gray')
plt.subplot(232)
plt.title('Testing Label')
plt.imshow(test_mask_argmax[:,:,n_slice])
plt.subplot(233)
plt.title('Prediction on test image')
plt.imshow(test_prediction_argmax[:,:, n_slice])
plt.show()
# Out:
# (128, 128, 128)
# (128, 128, 128)
# [0 1 2 3]

# %% [markdown]
# # validation images

# %%
img_num = 5

test_img = np.load("BraTS2020_TrainingData/input_data_128/val/images/image_"+str(img_num)+".npy")

test_mask = np.load("BraTS2020_TrainingData/input_data_128/val/masks/mask_"+str(img_num)+".npy")
test_mask_argmax=np.argmax(test_mask, axis=3)

test_img_input = np.expand_dims(test_img, axis=0)
test_prediction = model_2.predict(test_img_input)
test_prediction_argmax=np.argmax(test_prediction, axis=4)[0,:,:,:]


print(test_prediction_argmax.shape)
print(test_mask_argmax.shape)
print(np.unique(test_prediction_argmax))


#Plot individual slices from test predictions for verification
from matplotlib import pyplot as plt
import random

#n_slice=random.randint(0, test_prediction_argmax.shape[2])
n_slice = 55
plt.figure(figsize=(12, 8))
plt.subplot(231)
plt.title('Testing Image')
plt.imshow(test_img[:,:,n_slice,1], cmap='gray')
plt.subplot(232)
plt.title('Testing Label')
plt.imshow(test_mask_argmax[:,:,n_slice])
plt.subplot(233)
plt.title('Prediction on test image')
plt.imshow(test_prediction_argmax[:,:, n_slice])
plt.show()
# Out:
# (128, 128, 128)
# (128, 128, 128)
# [0 1 2 3]

# %%
model_2.save("brats_3d_model_2.hdf5")

# %%
history_2.history.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'mean_io_u', 'dice_coef_2', 'precision_2', 'sensitivity_2', 'specificity_2', 'dice_coef_necrotic_2', 'dice_coef_edema_2', 'dice_coef_enhancing_2', 'val_loss', 'val_accuracy', 'val_mean_io_u', 'val_dice_coef_2', 'val_precision_2', 'val_sensitivity_2', 'val_specificity_2', 'val_dice_coef_necrotic_2', 'val_dice_coef_edema_2', 'val_dice_coef_enhancing_2'])

# %%
# hist=history
#  dice_coef, precision, sensitivity, specificity, dice_coef_necrotic, dice_coef_edema ,dice_coef_enhancing
############### ########## ####### #######

hist=history_2.history

acc=hist['accuracy']
val_acc=hist['val_accuracy']

epoch=range(len(acc))

loss=hist['loss']
val_loss=hist['val_loss']

train_dice=hist['dice_coef_2']
val_dice=hist['val_dice_coef_2']

f,ax=plt.subplots(1,4,figsize=(16,8))

ax[0].plot(epoch,acc,'b',label='Training Accuracy')
ax[0].plot(epoch,val_acc,'r',label='Validation Accuracy')
ax[0].legend()

ax[1].plot(epoch,loss,'b',label='Training Loss')
ax[1].plot(epoch,val_loss,'r',label='Validation Loss')
ax[1].legend()

ax[2].plot(epoch,train_dice,'b',label='Training dice coef')
ax[2].plot(epoch,val_dice,'r',label='Validation dice coef')
ax[2].legend()

ax[3].plot(epoch,hist['loss'],'b',label='Training mean IOU')
ax[3].plot(epoch,hist['val_loss'],'r',label='Validation mean IOU')
ax[3].legend()
plt.savefig('training_result_2018.png')
plt.show()

# %%
# csv_logger = CSVLogger('evaluation_2018_3D_UNet.log')
model_2.compile(loss="categorical_crossentropy", optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001), 
                metrics = ['accuracy', dice_coef_2, precision_2, sensitivity_2, specificity_2, dice_coef_necrotic_2, dice_coef_edema_2, dice_coef_enhancing_2] )
# Evaluate the model on the test data using `evaluate`
print("Evaluate on test data")
results = model_2.evaluate(test_img_datagen, batch_size=16, 
                        #    callbacks= [csv_logger],
                           verbose =1, steps=test_steps_per_epoch)
li = ['accuracy', 'dice_coef_2', 'precision_2', 'sensitivity_2', 'specificity_2', 'dice_coef_necrotic_2', 'dice_coef_edema_2', 'dice_coef_enhancing_2']
for i in range(len(li)):
   print(f"{li[i]} {results[i]}")
# Out:
# Evaluate on test data
# 4/4 [==============================] - 11s 1s/step - loss: 0.0963 - accuracy: 0.9817 - dice_coef_2: 0.7657 - precision_2: 0.9824 - sensitivity_2: 0.9813 - specificity_2: 0.9942 - dice_coef_necrotic_2: 0.6044 - dice_coef_edema_2: 1.0659 - dice_coef_enhancing_2: 0.8387
# accuracy 0.09630531072616577
# dice_coef_2 0.9817148447036743
# precision_2 0.7657482624053955
# sensitivity_2 0.9824370741844177
# specificity_2 0.981288731098175
# dice_coef_necrotic_2 0.9941526055335999
# dice_coef_edema_2 0.6043910384178162
# dice_coef_enhancing_2 1.0658812522888184

# %%
#Verify IoU on a batch of images from the test dataset
#Using built in keras function for IoU
#Only works on TF > 2.0
from keras.metrics import MeanIoU

#Verify generator.... In python 3 next() is renamed as __next__()
test_image_batch, test_mask_batch = test_img_datagen.__next__()

test_mask_batch_argmax = np.argmax(test_mask_batch, axis=4)
test_pred_batch = model_2.predict(test_image_batch)
test_pred_batch_argmax = np.argmax(test_pred_batch, axis=4)

n_classes = 4
IOU_keras = MeanIoU(num_classes=n_classes)  
IOU_keras.update_state(test_pred_batch_argmax, test_mask_batch_argmax)
print("Mean IoU =", IOU_keras.result().numpy())
# Out:
# Mean IoU = 0.7390858
